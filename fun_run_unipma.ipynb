# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKai7/invoice_generator/blob/main/fun_run_unipma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang diperlukan
# !pip install gspread pandas fpdf2 pyqrcode pypng requests pillow
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2

# Import library yang dibutuhkan
import gspread
from google.colab import auth
from google.auth import default
import pandas as pd
from fpdf import FPDF
import os
from google.colab import drive
from datetime import datetime
import requests
from io import BytesIO
from PIL import Image
import urllib.parse
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Autentikasi Google Colab dengan Google Sheets & Drive
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Inisialisasi Google Drive API
drive_service = build('drive', 'v3', credentials=creds)

# Mount Google Drive untuk menyimpan invoice
drive.mount('/content/drive')

# Buka spreadsheet
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1mSceGaJlia1eb1U0iA-9RfU77b9D2SXH95AYjO1jyYM/edit?gid=0#gid=0"
sh = gc.open_by_url(spreadsheet_url)
worksheet = sh.get_worksheet(0)

# Ambil semua data dan periksa kolom yang tersedia
expected_headers = ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
records = worksheet.get_all_records(expected_headers=expected_headers)
df = pd.DataFrame.from_records(records)


# Periksa nama kolom yang sebenarnya
print("Kolom yang tersedia di spreadsheet:")
print(df.columns.tolist())

# Pastikan nama kolom sesuai dengan spreadsheet Anda
COLUMN_MAPPING = {
    'invoice_id': 'KODE_INVOICE',
    'name': 'NAMA',
    'category': 'KATEGORI',
    'barcode': 'BARCODE',
    'whatsapp': 'NO_WA',
    'address': 'ALAMAT'
}

# Path logo di Google Drive (sesuaikan dengan path Anda)
LOGO_DIES_PATH = '/content/drive/MyDrive/logo/diesnatalis 1-01.png'  # Ganti dengan path yang benar
LOGO_UNIPMA_PATH = '/content/drive/MyDrive/logo/Unipma.png'  # Ganti dengan path yang benar

class InvoicePDF(FPDF):
    def __init__(self, participant_data):
        super().__init__(format='A4', orientation='L')  # A4 Landscape
        self.participant_data = participant_data
        self.add_page()

    def header(self):
        # Tambahkan background dengan efek fade
        self._add_faded_background()

        # Tambahkan logo jika file ada
        try:
            # Logo Dies Natalis di kiri - ukuran disesuaikan
            if os.path.exists(LOGO_UNIPMA_PATH):
                self.image(LOGO_UNIPMA_PATH, x=15, y=15, w=30)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading UNIPMA logo: {e}")

        try:
            # Logo UNIPMA di kanan - ukuran disesuaikan
            if os.path.exists(LOGO_DIES_PATH):
                self.image(LOGO_DIES_PATH, x=210, y=0, w=100)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading Dies Natalis logo: {e}")

        # Judul
        self.set_y(25)
        self.set_font('Arial', 'B', 18)
        self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
        self.set_font('Arial', 'I', 12)
        self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
        self.ln(5)

    def _add_faded_background(self):
        # Path ke gambar background (sesuaikan dengan path Anda)
        BG_IMAGE_PATH = '/content/drive/MyDrive/logo/asset diesnat fun run/bg1.jpg'  # Ganti dengan path gambar background Anda

        if os.path.exists(BG_IMAGE_PATH):
            try:
                # Simpan posisi Y saat ini
                current_y = self.get_y()

                # Geser gambar 20px ke kiri (nilai negatif) dan perluas lebar untuk menutupi area yang kosong
                x_offset = -15  # Sesuaikan nilai ini untuk mengatur seberapa jauh ke kiri
                adjusted_width = self.w + abs(x_offset)  # Tambahkan lebar untuk kompensasi pergeseran

                # Tambahkan gambar background dengan opacity rendah
                self.image(BG_IMAGE_PATH, x=x_offset, y=0, w=adjusted_width, h=self.h)

                # Tambahkan layer semi-transparan untuk efek fade
                self.set_fill_color(255, 255, 255, 200)  # Putih dengan alpha 200/255 (~78% opacity)
                self.rect(0, 0, self.w, self.h, style='F')

                # Kembalikan posisi Y
                self.set_y(current_y)
            except Exception as e:
                print(f"⚠️ Error adding background: {e}")
        else:
            print("⚠️ Background image not found, skipping...")

    def footer(self):
        # Thank you message di bagian footer tengah
        self.set_y(-15)
        self.set_font('Arial', 'I', 12)
        self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')

    def create_invoice(self):
        # Informasi invoice
        self.set_font('Arial', 'B', 14)
        self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')

        # Tanggal
        self.set_font('Arial', '', 11)
        self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
        self.ln(8)

        # Garis pemisah
        self.line(10, self.get_y(), 287, self.get_y())
        self.ln(10)

        # Layout 3 kolom dengan alignment yang presisi
        col_width = 85
        start_y = self.get_y()  # Simpan posisi Y awal

        # Kolom 1: Data peserta
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
        self.set_font('Arial', '', 11)

        # Simpan posisi Y untuk alignment
        y_details = self.get_y()

        # Initialize name_y at the beginning
        name_y = y_details

        # Nama (baseline untuk alignment)
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Nama:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
        self.ln(2)
        name_y = self.get_y()

        # WhatsApp jika ada
        if COLUMN_MAPPING["whatsapp"] in self.participant_data and self.participant_data[COLUMN_MAPPING["whatsapp"]]:
            whatsapp_num = str(self.participant_data[COLUMN_MAPPING["whatsapp"]])
            clean_number = ''.join(filter(str.isdigit, whatsapp_num))
            if clean_number.startswith('0'):
                clean_number = '+62' + clean_number[1:]
            elif not clean_number.startswith('62'):
                clean_number = '+62' + clean_number
            else:
                clean_number = '+' + clean_number

            self.set_font('Arial', 'B', 11)
            self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
            self.set_font('Arial', '', 11)
            self.cell(col_width, 6, clean_number, ln=1, align='L')
            self.ln(2)

        # Alamat jika ada
        if COLUMN_MAPPING["address"] in self.participant_data:
            address = self.participant_data[COLUMN_MAPPING["address"]]
            if pd.notna(address) and str(address).strip() != '':
                self.set_font('Arial', 'B', 11)
                self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
                self.set_font('Arial', '', 11)
                self.multi_cell(col_width, 6, str(address), align='L')
                self.ln(2)

        # Kategori
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
        self.ln(2)

        # Kolom 2: Detail pengambilan race pack (tengah)
        self.set_xy(120, y_details - 5)  # Sejajar dengan "PARTICIPANT DETAILS"
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')

        # Posisikan konten race pack sejajar dengan "Name" di X=100
        self.set_xy(100, name_y - 10)  # X=100, Y sejajar dengan "Name"
        self.set_font('Arial', '', 11)

        # Format lengkap dengan indentasi yang tepat
        race_pack_content = [
          ("Tanggal:", 0),                     # Header - no indent
          ("- 30 Mei 2025", 0),                # Date 1 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-16.00", 10),       # Session 2 - indent 10
          ("- 31 Mei 2025", 0),                # Date 2 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-15.00", 10),       # Session 2 - indent 10
          ("", 0),                             # Empty line
          ("Lokasi:", 0),                      # Location header - no indent
          ("Laboratorium Terpadu UNIPMA", 0)   # Location - no indent
        ]

        # Cetak dengan indentasi yang konsisten
        for line, indent in race_pack_content:
            self.set_x(120 + indent)
            self.cell(col_width - indent, 6, line, ln=1, align='L')

        # Kolom 3: Barcode/QR code
        if COLUMN_MAPPING["barcode"] in self.participant_data and self.participant_data[COLUMN_MAPPING["barcode"]]:
            try:
                response = requests.get(self.participant_data[COLUMN_MAPPING["barcode"]])
                img = Image.open(BytesIO(response.content))

                temp_img_path = f"/tmp/barcode_{self.participant_data[COLUMN_MAPPING['invoice_id']]}.png"
                img.save(temp_img_path)

                # Posisi di kolom kanan, sejajar dengan "Name"
                x_position = 220
                y_position = name_y - 15  # Adjust to align with "Name"

                self.image(temp_img_path, x=x_position, y=y_position, w=60)

                # Teks di bawah barcode
                self.set_xy(x_position, y_position + 56)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')

                # Teks di bawah barcode 2
                self.set_xy(x_position, y_position + 61)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')

                os.remove(temp_img_path)
            except Exception as e:
                print(f"⚠️ Error adding barcode: {e}")

        # Notes di bagian bawah - diposisikan lebih tinggi
        notes_y = max(self.get_y() + 1, 120)  # Mengurangi 15pt dari posisi sebelumnya
        self.set_xy(10, notes_y)
        self.set_font('Arial', 'I', 11)
        notes = [
            "Catatan:",
            "- Harap datang tepat waktu sesuai sesi yang dipilih",
            "- Tunjukkan barcode ini saat pengambilan race pack",
            "- Bawa identitas yang valid (KTP/SIM/KTM/KARTU PELAJAR)"
        ]
        for note in notes:
            self.cell(0, 6, note, ln=1, align='L')

def generate_invoice_pdf(participant_data):
    # Buat PDF
    pdf = InvoicePDF(participant_data)
    pdf.create_invoice()

    # Buat folder penyimpanan di Colab
    local_invoice_dir = "/content/invoices"
    os.makedirs(local_invoice_dir, exist_ok=True)

    # Simpan PDF lokal
    pdf_filename = f"FUN RUN UNIPMA_{participant_data[COLUMN_MAPPING['invoice_id']]}.pdf"
    local_pdf_path = f"{local_invoice_dir}/{pdf_filename}"
    pdf.output(local_pdf_path)

    return local_pdf_path, pdf_filename

def upload_to_drive(file_path, file_name, folder_id=None):
    """Upload file ke Google Drive dan set permissions"""
    file_metadata = {
        'name': file_name,
        'parents': [folder_id] if folder_id else None
    }

    media = MediaFileUpload(file_path, mimetype='application/pdf')

    file = drive_service.files().create(
        body=file_metadata,
        media_body=media,
        fields='id,webViewLink'
    ).execute()

    # Set permissions agar bisa diakses oleh siapa saja dengan link
    permission = {
        'type': 'anyone',
        'role': 'reader'
    }

    drive_service.permissions().create(
        fileId=file['id'],
        body=permission
    ).execute()

    return file['webViewLink']

def generate_whatsapp_link(phone_number):
    if pd.isna(phone_number) or not phone_number:
        return ""

    # Format nomor WhatsApp (62XXXXXXXXXX)
    clean_number = ''.join(filter(str.isdigit, str(phone_number)))
    if clean_number.startswith('0'):
        clean_number = '62' + clean_number[1:]
    elif not clean_number.startswith('62'):
        clean_number = '62' + clean_number
    return f"https://wa.me/{clean_number}"

def generate_message_template(participant_data, drive_link):
    # Format WhatsApp number dengan +62
    whatsapp_num = str(participant_data.get(COLUMN_MAPPING['whatsapp'], ''))
    if whatsapp_num:
        clean_number = ''.join(filter(str.isdigit, whatsapp_num))
        if clean_number.startswith('0'):
            clean_number = '+62' + clean_number[1:]
        elif not clean_number.startswith('62'):
            clean_number = '+62' + clean_number
        else:
            clean_number = '+' + clean_number
    else:
        clean_number = ''

    return f"""
Halo {participant_data[COLUMN_MAPPING['name']]},

Terima kasih telah mendaftar di *UNIPMA FUN RUN 5K 2025*!
Berikut invoice resmi Anda:

🔹 *Kode Invoice:* {participant_data[COLUMN_MAPPING['invoice_id']]}
🔹 *Kategori:* {participant_data[COLUMN_MAPPING['category']]}
🔹 *Alamat:* {participant_data[COLUMN_MAPPING['address']]}


📥 *Download Invoice:*
{drive_link}

*Info Pengambilan Race Pack:*
📅 *Tanggal:*
- 30 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-16.00)
- 31 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-15.00)
🏫 *Lokasi:* Laboratorium Terpadu UNIPMA

*Catatan:*
- Harap datang tepat waktu sesuai sesi yang dipilih
- Tunjukkan barcode yang ada pada invoice saat pengambilan racepack
- Bawa identitas yang valid(KTP/SIM/KTM/KARTU PELAJAR)

Mohon simpan invoice ini sebagai bukti pendaftaran.
Jika ada pertanyaan, hubungi kami via WhatsApp.

Salam,
*Panitia Unipma Fun Run 5K 2025*
"""

def process_all_participants():
    updates = []
    errors = []

    # ID folder tujuan di Google Drive (ganti dengan folder ID Anda)
    DRIVE_FOLDER_ID = '1A8ADXVlMOHPJsBhvaxZuBjL7egO3Wq2_'  # Ganti dengan folder ID tujuan

    for index, row in df.iterrows():
        try:
            invoice_id = row[COLUMN_MAPPING['invoice_id']]
            print(f"\nMemproses peserta: {row.get(COLUMN_MAPPING['name'], '')} (Invoice: {invoice_id})")

            # 1. Generate PDF
            local_pdf_path, pdf_filename = generate_invoice_pdf(row)

            # 2. Upload ke Google Drive dan dapatkan link
            drive_link = upload_to_drive(local_pdf_path, pdf_filename, DRIVE_FOLDER_ID)
            print(f"✅ Invoice diupload ke: {drive_link}")

            # 3. Generate link WhatsApp
            whatsapp_link = generate_whatsapp_link(row.get(COLUMN_MAPPING['whatsapp'], ''))
            updates.append((index, 'link_whatsapp', whatsapp_link))

            # 4. Buat template pesan
            message = generate_message_template(row, drive_link)
            updates.append((index, 'template_pesan', message))

            # 5. Bersihkan file lokal
            os.remove(local_pdf_path)

        except Exception as e:
            error_msg = f"❌ Error saat memproses {row.get(COLUMN_MAPPING['name'], '')}: {str(e)}"
            print(error_msg)
            errors.append((index, error_msg))

    # Update spreadsheet
    for update in updates:
        row_idx, col_name, value = update
        try:
            # Cari kolom yang sesuai
            col_names = [col.lower() for col in df.columns]
            target_col = col_name.lower()

            if target_col in col_names:
                col_idx = col_names.index(target_col) + 1  # +1 karena indeks spreadsheet mulai dari 1
                worksheet.update_cell(row_idx + 2, col_idx, value)
                print(f"✔️ Updated {col_name} untuk baris {row_idx + 2}")
            else:
                print(f"⚠️ Kolom {col_name} tidak ditemukan di spreadsheet")
        except Exception as e:
            print(f"❌ Gagal mengupdate spreadsheet untuk baris {row_idx}: {str(e)}")

    # Tampilkan error summary
    if errors:
        print("\n⛔ Error Summary:")
        for error in errors:
            print(error[1])

# Jalankan proses utama
process_all_participants()
print("\n✅ Proses selesai!")
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.11/dist-packages (6.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: fpdf2 in /usr/local/lib/python3.11/dist-packages (2.8.3)
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: pypng in /usr/local/lib/python3.11/dist-packages (0.20220715.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from gspread) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gspread) (1.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (4.58.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.38.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.4.26)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Kolom yang tersedia di spreadsheet:
# ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
#
# Memproses peserta: Riawati Azizah (Invoice: RIA-1-8509)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# <ipython-input-2-ed1da1abe194>:88: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 18)
# <ipython-input-2-ed1da1abe194>:89: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
# <ipython-input-2-ed1da1abe194>:90: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-2-ed1da1abe194>:91: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
# <ipython-input-2-ed1da1abe194>:129: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 14)
# <ipython-input-2-ed1da1abe194>:130: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')
# <ipython-input-2-ed1da1abe194>:133: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:134: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
# <ipython-input-2-ed1da1abe194>:146: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-2-ed1da1abe194>:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
# <ipython-input-2-ed1da1abe194>:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:157: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-2-ed1da1abe194>:158: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Nama:', ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:159: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:160: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:175: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-2-ed1da1abe194>:176: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:177: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:178: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, clean_number, ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:185: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-2-ed1da1abe194>:186: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:187: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:192: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-2-ed1da1abe194>:193: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:194: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:195: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:200: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-2-ed1da1abe194>:201: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')
# <ipython-input-2-ed1da1abe194>:205: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-2-ed1da1abe194>:224: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width - indent, 6, line, ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:243: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-2-ed1da1abe194>:244: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')
# <ipython-input-2-ed1da1abe194>:248: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-2-ed1da1abe194>:249: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')
# <ipython-input-2-ed1da1abe194>:258: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 11)
# <ipython-input-2-ed1da1abe194>:266: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 6, note, ln=1, align='L')
# <ipython-input-2-ed1da1abe194>:124: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-2-ed1da1abe194>:125: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=0 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1IvlzdSNZeK5pMCUwOvP3K6n1gHAgeuQe/view?usp=drivesdk
#
# Memproses peserta: Fadhil Chivo Adriansyah  (Invoice: FAD-1-4154)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/167siOZXbEAdGtad57Em25cZDSWuLS6oY/view?usp=drivesdk
#
# Memproses peserta: DAFA REZKY YUDA IRIANTO (Invoice: DAF-1-7683)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1QQHb8vIIbuo0AKpaAGNhU14xG7wNJqa8/view?usp=drivesdk
#
# Memproses peserta: FAMA FADHILA DWI KURNIATI (Invoice: FAM-1-2196)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1k8VY03hNa52d2qnrpnA9lp5GeqdIMIHl/view?usp=drivesdk
#
# Memproses peserta: angely yudhiska (Invoice: ANG-1-9311)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xaOUApTjAOvxj-HHuXhlL0k9s_bvowZO/view?usp=drivesdk
#
# Memproses peserta: Muhamad Novian Saputra (Invoice: MUH-1-3212)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1QVcKxHS-c9H3th3U1MFoKZc6fAK4zAWf/view?usp=drivesdk
#
# Memproses peserta: Feny Hasta Yulita (Invoice: FEN-1-3300)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Xw_17LZx6tRhMAZzH-v7bp3qEpNyT13U/view?usp=drivesdk
#
# Memproses peserta: VIVIN DWI CINTA LAURA  (Invoice: VIV-1-4265)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1edHiCX1njoOiEcqRNKOCKoXs8XIzzGJl/view?usp=drivesdk
#
# Memproses peserta: Adelya montana (Invoice: ADE-1-8104)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1bqpGR8huee8e3bR8CzSEPNqP4ZnupGuq/view?usp=drivesdk
#
# Memproses peserta: Nayra Anike Prastika (Invoice: NAY-1-4404)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1XPhX7l05idj9MH1EuRUH4413d9eiVbu9/view?usp=drivesdk
#
# Memproses peserta: AQIB GHAISANI (Invoice: AQI-1-3779)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19yvUmZa1mnpFG1sxjnbC-DzB-J0VIoO8/view?usp=drivesdk
#
# Memproses peserta: Adelya Oktavia Permatasari  (Invoice: ADE-1-4424)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mEq4ydDl4iRNxg4eFnSjPy2iu7yyCYvm/view?usp=drivesdk
#
# Memproses peserta: NAJWA BATRISYIA RAFEYFA ZURIA (Invoice: NAJ-1-3420)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1erlbHEwiDFE6HiCHSEk7G78CmavbGKo_/view?usp=drivesdk
#
# Memproses peserta: ANJAR AYU SULISTYOWATI NINGSIH (Invoice: ANJ-1-6578)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1v2URse_0NjVEjPgxCGU4zXeTulh0IHDf/view?usp=drivesdk
#
# Memproses peserta: WILDAN ADITYA SALIM (Invoice: WIL-1-6914)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1DW9y9VlykfpDhVJ4LW3qd3fav3to3uGn/view?usp=drivesdk
#
# Memproses peserta: Alifa Bambang Ayyuni (Invoice: ALI-1-2422)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1V-K64mrpIOdeQQ3aEt0hAOgZ21_mwKqU/view?usp=drivesdk
#
# Memproses peserta: MADAN RIMBA ANDINO (Invoice: MAD-1-1188)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1gFcMYEXsvl0lccZW1bIwhCADI4MoYREW/view?usp=drivesdk
#
# Memproses peserta: Putri rifka Almaheraa (Invoice: PUT-1-7002)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jDBHzYj7xckKVPgf9hJRWcvRg3tt4mWT/view?usp=drivesdk
#
# Memproses peserta: arumi mayang nur aini (Invoice: ARU-1-5552)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/15hsohkfcyVMVrfHVaexKo5JBclX7Mltp/view?usp=drivesdk
#
# Memproses peserta: ALIFILIA AZIZAHTUL ULYA (Invoice: ALI-1-3207)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1doRG4nHvqMvlYZdPfRR88CAQZHlzaFIw/view?usp=drivesdk
#
# Memproses peserta: Dea Anata Wijaya Tanjung  (Invoice: DEA-1-9468)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1QbFgaB7WJR_bM9kWqFL0TjHVR1qjoE_s/view?usp=drivesdk
#
# Memproses peserta: Latifah Nur ‘Aini (Invoice: LAT-1-1685)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ❌ Error saat memproses Latifah Nur ‘Aini: Character "‘" at index 12 in text is outside the range of characters supported by the font used: "helvetica". Please consider using a Unicode font.
#
# Memproses peserta: Daffa Al-Kautsar  (Invoice: DAF-1-5157)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/109C2exZRT3vv-T19r1UiQJNDgGfGpzIi/view?usp=drivesdk
#
# Memproses peserta: Raditya Agustian Pratama (Invoice: RAD-1-0876)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19WJgAUeNd03No-xHe3rijcLoJYYqNtxH/view?usp=drivesdk
#
# Memproses peserta: Yohanes Alkinus Birmanto  (Invoice: YOH-1-2162)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1qLWUQ_kZdvgE68vAjRwS_2rgtCxy8Ilq/view?usp=drivesdk
#
# Memproses peserta: sabrina putri efendi  (Invoice: SAB-1-1864)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1a_HY95ySRiDsQCnIS19q9gu55G2NC62t/view?usp=drivesdk
#
# Memproses peserta: regilia heppi mugianata (Invoice: REG-1-7415)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Ie8Z39f3bQwPZF3dlTdyfR_xMRBailCZ/view?usp=drivesdk
#
# Memproses peserta: Risma Ayu Desinta Putri (Invoice: RIS-1-9214)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1hJAmopmuY1DmHEQjHK_1tFSah2hnDDsi/view?usp=drivesdk
#
# Memproses peserta: SAFA DWI ANGGRAINI  (Invoice: SAF-1-5927)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Hs8MtJBegA0XV0Ow9nlL0Z4QgJqaEV8k/view?usp=drivesdk
#
# Memproses peserta: Fauzi Jonata  (Invoice: FAU-1-2689)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1SB6KwnJDCnLuBpZevOGPotiPo6DO3hwe/view?usp=drivesdk
#
# Memproses peserta: Iffat Putra Wibowo (Invoice: IFF-1-1949)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OEqcLxoZwK4D1XPbBGfxbP59NNV6rolp/view?usp=drivesdk
#
# Memproses peserta: MUHAMMAD FAUZAN MUBAROK  (Invoice: MUH-1-1436)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1YhW2IuZUTizv1zIMmVWQCbpNMH_TqzPI/view?usp=drivesdk
#
# Memproses peserta: GALANG JATI AKMAL (Invoice: GAL-1-0982)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/136cXwfdzO9XDyzDrVKlKhjCiUFuMqJND/view?usp=drivesdk
#
# Memproses peserta: NANDO HAFISH PRIHARNANTA  (Invoice: NAN-1-9930)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1elE6bUmElaXO_pDuu08rFelvSSQ6XxaS/view?usp=drivesdk
#
# Memproses peserta: DZAKY RAISSA AKABR HARIANTO PUTRA (Invoice: DZA-1-1901)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13nwc90o0GuPGVsez6C8hWcA1yxkYO1y5/view?usp=drivesdk
#
# Memproses peserta: Bintang Albyan Pramudya Wijaya (Invoice: BIN-1-8375)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WW21OJ0x6bWQDY9EyZSQNNFMHuuGdnn6/view?usp=drivesdk
#
# Memproses peserta: Daffa Marsa Leviana (Invoice: DAF-1-2684)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1JYTImO6aH2kuBZU90b9OFfFsMc7H53Q3/view?usp=drivesdk
#
# Memproses peserta: Muhammad Adnawegiseva Galang Ramadhan (Invoice: MUH-1-2264)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MExKFD7sfLFuDotAcLBwOyywYQEcQVsM/view?usp=drivesdk
#
# Memproses peserta: Shandy rizki ardiansyah  (Invoice: SHA-1-1521)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1T_Rz10Xpo1E4uf6IrN1M71Ixwn9HCdtE/view?usp=drivesdk
#
# Memproses peserta: Muhammad Gama Rimbawan  (Invoice: MUH-1-3633)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/12-8bG9Ii4bKKzifPqY8qqrzBACxyWrxQ/view?usp=drivesdk
#
# Memproses peserta: Januarius Mimin (Invoice: JAN-1-7634)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1AXRXYFzb2AN8Cye78zj5xh4HKq-AY9uO/view?usp=drivesdk
#
# Memproses peserta: ARDYAN SAPTA NARUTAMA  (Invoice: ARD-1-5321)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1J747dpgybK4CyfS4rNB0LzBiw3SKPDNC/view?usp=drivesdk
#
# Memproses peserta: FITRIA SANI MAHABBAH (Invoice: FIT-1-1869)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/18bqK0elq-CD38jgGChchSljzG-uf2N29/view?usp=drivesdk
#
# Memproses peserta: Anita Rachmawati  (Invoice: ANI-1-8877)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1811V8SQEfy9y9PvN1l_rSseqPPtzPYxx/view?usp=drivesdk
#
# Memproses peserta: Malika Alya Septiani Mutia (Invoice: MAL-1-5858)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1kf8W0VViUocwbVZMcPZn_M1nVTx1MyZR/view?usp=drivesdk
#
# Memproses peserta: SHAKILLA LAURA ADIFA (Invoice: SHA-1-3597)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1e8JzgvDF4apWwUpm8agxnGlCN-t61LcH/view?usp=drivesdk
#
# Memproses peserta: Cedric whitsel melandri (Invoice: CED-1-7730)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1lExegH_bzJzOqQjh2nTf5wvapmdfu0xr/view?usp=drivesdk
#
# Memproses peserta: Girlstya Ardistry (Invoice: GIR-1-0822)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zGSq-q0UcssKianJtiEvq9LQflFQz3Ld/view?usp=drivesdk
#
# Memproses peserta: Amelya Zahra (Invoice: AME-1-9819)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vtHjejhxspgvEygkbN0F1qwOgXEq1fZY/view?usp=drivesdk
#
# Memproses peserta: Arga adi susilo (Invoice: ARG-1-5632)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/165YbVVKK8jF7unF5IYb0utr_pZ4NFOwT/view?usp=drivesdk
#
# Memproses peserta: muhajid tri atmaja  (Invoice: MUH-1-9664)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11ufkhV2ZzG-MPaoMq2J0KBorw4iWw5f2/view?usp=drivesdk
#
# Memproses peserta: ANDRYAN ANGGA IRAWAN (Invoice: AND-1-5770)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1aZLyRhpWVj8Eqm_kZoVD9c3fMmQGtn2t/view?usp=drivesdk
#
# Memproses peserta: RAYAVEN MAHAA PUTRA PRADANA  (Invoice: RAY-1-5463)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1h7Uo_muOLcevpuxBoUqu61o4K__sl2-k/view?usp=drivesdk
#
# Memproses peserta: GAYUK ADICA JUNIOR (Invoice: GAY-1-1809)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1uGna3xgCRlzFzB5ywAvy_E_J9ryQhOqj/view?usp=drivesdk
#
# Memproses peserta: SYAHARA ARDITIA VERNANDA  (Invoice: SYA-1-1198)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vrSy23t4QJT8emp1_QTb4BsmjgJe6mgU/view?usp=drivesdk
#
# Memproses peserta: DENISCHA FANY NADIRA  (Invoice: DEN-1-4074)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xiWzCzVr4g2GpzbDAdmIq1SBNE0UsenB/view?usp=drivesdk
#
# Memproses peserta: Eka Sulistyawati (Invoice: EKA-1-2616)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Uc3TZe96IXreM4-4w1VdaeRXxJVOyr8a/view?usp=drivesdk
#
# Memproses peserta: KEYZ ANKCHA JARWOTO SULISTYA putra (Invoice: KEY-1-5220)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fpgv60OklpxmBxs2FFwaPE7LWeQdwEaf/view?usp=drivesdk
#
# Memproses peserta: DWIKI WANDANI (Invoice: DWI-1-6225)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/16EjjiaG_WNDdz5FUUcyifJvn6NbKEXzi/view?usp=drivesdk
#
# Memproses peserta: KEYZ ANKCHA JARWOTO SULISTYA putra (Invoice: KEY-1-4038)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1EjKCz_QpdhH8ywC6SLC79vPalU8d1bm2/view?usp=drivesdk
#
# Memproses peserta: Aris Kurniawan  (Invoice: ARI-1-2701)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1taO_xsIfYZX-HJCZ0KDsUA33acIpCRD5/view?usp=drivesdk
#
# Memproses peserta: AZHAHRAPUJA LAILA  (Invoice: AZH-1-6479)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TkeQeqy7hHu8g_erJoBclzK4kHjNWXDd/view?usp=drivesdk
#
# Memproses peserta: Muhammad dzakwan hilmy baskoro (Invoice: MUH-1-7090)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1t7pAKKdeIbEXkKS6n1n-DX3ycOBcacum/view?usp=drivesdk
#
# Memproses peserta: Hafizh Kurniawan Putra Santoso (Invoice: HAF-1-4141)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1JFO9KqbcVfq7OQGCcz1hO-qbtS2d-zOo/view?usp=drivesdk
#
# Memproses peserta: Muhammad Rafly Nur Rochman (Invoice: MUH-1-4705)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1EarsGtxWwIAvrG_7Ss79s570v3QCNgdw/view?usp=drivesdk
#
# Memproses peserta: Elsa Ginanjarwati (Invoice: ELS-1-4155)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1VIMcuhYgHFoF1J51R6Q-gBvQGlkVkApk/view?usp=drivesdk
#
# Memproses peserta: Aulia Noventika Fadiliyah  (Invoice: AUL-1-7362)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MK-sAD-At4T5kx_VAkn-NUP5Q2tS9ic_/view?usp=drivesdk
#
# Memproses peserta: REVA MARDANI MUSTABSIROH (Invoice: REV-1-1411)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/17zAFdHUZspeG6TQSZAYDBVBd7TJWD8bO/view?usp=drivesdk
#
# Memproses peserta: FAISAL RAMADHANSYAH  (Invoice: FAI-1-5458)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MnT5kImG2tO-AHMez65WdHm6W-ZJnkAS/view?usp=drivesdk
#
# Memproses peserta: Alif Akbar Rahmat Hakim (Invoice: ALI-1-7306)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/161cny21x1qx3FhQe9f0eFbdcMaJpLsV6/view?usp=drivesdk
#
# Memproses peserta: Zana Clein Taalea Wibowo (Invoice: ZAN-1-8877)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11h74_MuTUm5if-CtUnHgIKKj1RmarvmJ/view?usp=drivesdk
#
# Memproses peserta: RAHMAT (Invoice: RAH-1-1269)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/153RfOXUXDs6TO2UC8vNl_EwWw6UbQqF4/view?usp=drivesdk
#
# Memproses peserta: Fauzan Mahendra Widianto Putra (Invoice: FAU-1-6249)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RxOQcT930FMRzwFsQ_kSEdpu--GYcrvK/view?usp=drivesdk
#
# Memproses peserta: Rifa Rohadatul 'Aisy (Invoice: RIF-1-4177)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1rRtnWbJ6w3N6bA61OiXM6Gj7lB8TRD7d/view?usp=drivesdk
#
# Memproses peserta: FATTAN ARVENT MAULANA ALTHAFI (Invoice: FAT-1-1002)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1k_PbvvH1y3oKwpH2AYOcmXoXwVJ8GYT8/view?usp=drivesdk
#
# Memproses peserta: Richard Ilham  (Invoice: RIC-1-2302)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1NRFdtKy2ZUjrdv38kr-V1FZe3XjEv_a-/view?usp=drivesdk
#
# Memproses peserta: ALFIN KHOIRUL HERMANSYAH  (Invoice: ALF-1-9742)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1p0DTiJnA_Jiwir3XVFxHzra74BiT8uxA/view?usp=drivesdk
#
# Memproses peserta: Linda Rahayu  (Invoice: LIN-1-8491)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10pi6bd_x5wEW0P6-vWOYli_58Kek6exg/view?usp=drivesdk
#
# Memproses peserta: DIFA (Invoice: DIF-1-9868)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1sD0qW7uofHboLrACoWlrh4JUMySfbRqn/view?usp=drivesdk
#
# Memproses peserta: HAYU DYAH PURBOSARI (Invoice: HAY-1-9742)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Vrye7IG_tvoFtHyDnFGnXVCH5kLAI2km/view?usp=drivesdk
#
# Memproses peserta: Bagas Dwi Laksana  (Invoice: BAG-1-1791)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1GD3Cs3N8eSz3rJcxeoC7R2x_LWuTkI2c/view?usp=drivesdk
#
# Memproses peserta: MUHAMMAD ASYRAF AS-SHIDDIQI (Invoice: MUH-1-3544)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13KwV51emf2lxQSJwH12XV1ShRJIrP8Jd/view?usp=drivesdk
#
# Memproses peserta: MUHAMMAD AFIF SOLIQHIN (Invoice: MUH-1-9912)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1X-SQQC4V9Z6_YFnC1-3M6vNYmeC4I4BD/view?usp=drivesdk
#
# Memproses peserta: AGUSTINA VIA ROSYIDAH (Invoice: AGU-1-3633)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/12FMnYfJ_qHzRmCW6QfqL3I3cLw4Fi3zd/view?usp=drivesdk
#
# Memproses peserta: AFRIZAL AZIZ ESNI KAUTSAR (Invoice: AFR-1-8533)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1gwAW4TeZ8Yrs7YlPJ08-XNIrGlsm0zKO/view?usp=drivesdk
#
# Memproses peserta: Sifti nachdiatul ummah (Invoice: SIF-1-7060)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10AuX0VbcPRUsFYPNswsr39IlNmimOt9D/view?usp=drivesdk
#
# Memproses peserta: Gusnia Gilang bajikantara (Invoice: GUS-1-5449)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Za6Ru4iHbC8UjoY2fXqd0jV3yezAIwt1/view?usp=drivesdk
#
# Memproses peserta: Alfahrizi Fauza Ramadhan (Invoice: ALF-1-3530)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1lVShVYeI4k25mNQYDsZdouiAqgdfbb2A/view?usp=drivesdk
#
# Memproses peserta: Rifqiansyah Arya Putra Erdana (Invoice: RIF-1-3395)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_bZMeTWdWcAz6IuMIPdbrocsz8kBgMgT/view?usp=drivesdk
#
# Memproses peserta: NAUFAL ANNORA ICHWAN  (Invoice: NAU-1-6058)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13vFPIBOL1DY8G-S_BaD0UgYfWL6m8wXB/view?usp=drivesdk
#
# Memproses peserta: ENDRA KUSUMA SATYA BRATA (Invoice: END-1-9464)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jp9fHEslv2RJhFuB63Ot6BtiF6GEFHdc/view?usp=drivesdk
#
# Memproses peserta: SYARIZAL AGAM MAHENDRA (Invoice: SYA-1-2759)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/165_Hh4leaAbei-_L55diq99-Wv4TenCJ/view?usp=drivesdk
#
# Memproses peserta: Sri Lestari (Invoice: SRI-1-7344)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_DDzM5dG9BS5Naf_o27DanlyUzyltIFG/view?usp=drivesdk
#
# Memproses peserta: Harvano Arkhan Prima Adyatma (Invoice: HAR-1-4476)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1rOReE9fLq7VS41mg_oD9_7FcRRUXM0z1/view?usp=drivesdk
#
# Memproses peserta: Aisyah Sa'adah  (Invoice: AIS-1-4925)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_Z1LJJE8ZiakBhUvTbecF-kicKRyPhv-/view?usp=drivesdk
#
# Memproses peserta: Catur Wibowo (Invoice: CAT-1-5051)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zoh0gtFGw67E5-m8I09qiZbbCW7ORa3O/view?usp=drivesdk
#
# Memproses peserta: PRAMESTY CITRA MEISYA BILQIS  (Invoice: PRA-1-1058)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vHCelIlNJn8usglPYYOv05zCTsjUXm3P/view?usp=drivesdk
#
# Memproses peserta: DESY ULIASARI (Invoice: DES-1-5364)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1S4p8sAEw0TU76y3lZk3NO0ABP7t7Kj8S/view?usp=drivesdk
#
# Memproses peserta: YUYUN DWI PANGESTI (Invoice: YUY-1-7858)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1IP9o1q2Kui3pAbhTnGCYPGKJtyBEsTz5/view?usp=drivesdk
#
# Memproses peserta: MIKE INDAH SETYA SARI (Invoice: MIK-1-7858)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1N5Z5mAv96YeCw9J_FIJefkF_40gymxHx/view?usp=drivesdk
#
# Memproses peserta: NOVITA DIYAH AYU PRATIWI (Invoice: NOV-1-5131)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RwgumCs8d4grCDyrk7dsrCkLSyun8Y7z/view?usp=drivesdk
#
# Memproses peserta: KURNIAWATI WAHYU UTAMI (Invoice: KUR-1-5973)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1z8LcXNvGEwmIU88ENWK7EyqeoShyLLQa/view?usp=drivesdk
#
# Memproses peserta: DIRA LAURENZA MAHARDIKA SARI (Invoice: DIR-1-5973)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10Be9toMwQVfHZz1CtSMGUice3Y8EoE2G/view?usp=drivesdk
#
# Memproses peserta: USMAN SOFYAN (Invoice: USM-1-8003)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19uhBAauiOrNLoEJcxuV_kf-9oeJnr2KE/view?usp=drivesdk
# ✔️ Updated link_whatsapp untuk baris 2
# ✔️ Updated template_pesan untuk baris 2
# ✔️ Updated link_whatsapp untuk baris 3
# ✔️ Updated template_pesan untuk baris 3
# ✔️ Updated link_whatsapp untuk baris 4
# ✔️ Updated template_pesan untuk baris 4
# ✔️ Updated link_whatsapp untuk baris 5
# ✔️ Updated template_pesan untuk baris 5
# ✔️ Updated link_whatsapp untuk baris 6
# ✔️ Updated template_pesan untuk baris 6
# ✔️ Updated link_whatsapp untuk baris 7
# ✔️ Updated template_pesan untuk baris 7
# ✔️ Updated link_whatsapp untuk baris 8
# ✔️ Updated template_pesan untuk baris 8
# ✔️ Updated link_whatsapp untuk baris 9
# ✔️ Updated template_pesan untuk baris 9
# ✔️ Updated link_whatsapp untuk baris 10
# ✔️ Updated template_pesan untuk baris 10
# ✔️ Updated link_whatsapp untuk baris 11
# ✔️ Updated template_pesan untuk baris 11
# ✔️ Updated link_whatsapp untuk baris 12
# ✔️ Updated template_pesan untuk baris 12
# ✔️ Updated link_whatsapp untuk baris 13
# ✔️ Updated template_pesan untuk baris 13
# ✔️ Updated link_whatsapp untuk baris 14
# ✔️ Updated template_pesan untuk baris 14
# ✔️ Updated link_whatsapp untuk baris 15
# ✔️ Updated template_pesan untuk baris 15
# ✔️ Updated link_whatsapp untuk baris 16
# ✔️ Updated template_pesan untuk baris 16
# ✔️ Updated link_whatsapp untuk baris 17
# ✔️ Updated template_pesan untuk baris 17
# ✔️ Updated link_whatsapp untuk baris 18
# ✔️ Updated template_pesan untuk baris 18
# ✔️ Updated link_whatsapp untuk baris 19
# ✔️ Updated template_pesan untuk baris 19
# ✔️ Updated link_whatsapp untuk baris 20
# ✔️ Updated template_pesan untuk baris 20
# ✔️ Updated link_whatsapp untuk baris 21
# ✔️ Updated template_pesan untuk baris 21
# ✔️ Updated link_whatsapp untuk baris 22
# ✔️ Updated template_pesan untuk baris 22
# ✔️ Updated link_whatsapp untuk baris 24
# ✔️ Updated template_pesan untuk baris 24
# ✔️ Updated link_whatsapp untuk baris 25
# ✔️ Updated template_pesan untuk baris 25
# ✔️ Updated link_whatsapp untuk baris 26
# ✔️ Updated template_pesan untuk baris 26
# ✔️ Updated link_whatsapp untuk baris 27
# ✔️ Updated template_pesan untuk baris 27
# ✔️ Updated link_whatsapp untuk baris 28
# ✔️ Updated template_pesan untuk baris 28
# ✔️ Updated link_whatsapp untuk baris 29
# ✔️ Updated template_pesan untuk baris 29
# ✔️ Updated link_whatsapp untuk baris 30
# ✔️ Updated template_pesan untuk baris 30
# ✔️ Updated link_whatsapp untuk baris 31
# ✔️ Updated template_pesan untuk baris 31
# ✔️ Updated link_whatsapp untuk baris 32
# ✔️ Updated template_pesan untuk baris 32
# ✔️ Updated link_whatsapp untuk baris 33
# ✔️ Updated template_pesan untuk baris 33
# ✔️ Updated link_whatsapp untuk baris 34
# ✔️ Updated template_pesan untuk baris 34
# ✔️ Updated link_whatsapp untuk baris 35
# ✔️ Updated template_pesan untuk baris 35
# ✔️ Updated link_whatsapp untuk baris 36
# ✔️ Updated template_pesan untuk baris 36
# ✔️ Updated link_whatsapp untuk baris 37
# ✔️ Updated template_pesan untuk baris 37
# ✔️ Updated link_whatsapp untuk baris 38
# ✔️ Updated template_pesan untuk baris 38
# ✔️ Updated link_whatsapp untuk baris 39
# ✔️ Updated template_pesan untuk baris 39
# ✔️ Updated link_whatsapp untuk baris 40
# ✔️ Updated template_pesan untuk baris 40
# ✔️ Updated link_whatsapp untuk baris 41
# ✔️ Updated template_pesan untuk baris 41
# ✔️ Updated link_whatsapp untuk baris 42
# ✔️ Updated template_pesan untuk baris 42
# ✔️ Updated link_whatsapp untuk baris 43
# ✔️ Updated template_pesan untuk baris 43
# ✔️ Updated link_whatsapp untuk baris 44
# ✔️ Updated template_pesan untuk baris 44
# ✔️ Updated link_whatsapp untuk baris 45
# ✔️ Updated template_pesan untuk baris 45
# ✔️ Updated link_whatsapp untuk baris 46
# ✔️ Updated template_pesan untuk baris 46
# ✔️ Updated link_whatsapp untuk baris 47
# ✔️ Updated template_pesan untuk baris 47
# ✔️ Updated link_whatsapp untuk baris 48
# ✔️ Updated template_pesan untuk baris 48
# ✔️ Updated link_whatsapp untuk baris 49
# ✔️ Updated template_pesan untuk baris 49
# ✔️ Updated link_whatsapp untuk baris 50
# ✔️ Updated template_pesan untuk baris 50
# ✔️ Updated link_whatsapp untuk baris 51
# ✔️ Updated template_pesan untuk baris 51
# ✔️ Updated link_whatsapp untuk baris 52
# ✔️ Updated template_pesan untuk baris 52
# ✔️ Updated link_whatsapp untuk baris 53
# ✔️ Updated template_pesan untuk baris 53
# ✔️ Updated link_whatsapp untuk baris 54
# ✔️ Updated template_pesan untuk baris 54
# ✔️ Updated link_whatsapp untuk baris 55
# ✔️ Updated template_pesan untuk baris 55
# ✔️ Updated link_whatsapp untuk baris 56
# ✔️ Updated template_pesan untuk baris 56
# ✔️ Updated link_whatsapp untuk baris 57
# ✔️ Updated template_pesan untuk baris 57
# ✔️ Updated link_whatsapp untuk baris 58
# ✔️ Updated template_pesan untuk baris 58
# ✔️ Updated link_whatsapp untuk baris 59
# ✔️ Updated template_pesan untuk baris 59
# ✔️ Updated link_whatsapp untuk baris 60
# ✔️ Updated template_pesan untuk baris 60
# ✔️ Updated link_whatsapp untuk baris 61
# ✔️ Updated template_pesan untuk baris 61
# ✔️ Updated link_whatsapp untuk baris 62
# ✔️ Updated template_pesan untuk baris 62
# ✔️ Updated link_whatsapp untuk baris 63
# ✔️ Updated template_pesan untuk baris 63
# ✔️ Updated link_whatsapp untuk baris 64
# ✔️ Updated template_pesan untuk baris 64
# ✔️ Updated link_whatsapp untuk baris 65
# ✔️ Updated template_pesan untuk baris 65
# ✔️ Updated link_whatsapp untuk baris 66
# ✔️ Updated template_pesan untuk baris 66
# ✔️ Updated link_whatsapp untuk baris 67
# ✔️ Updated template_pesan untuk baris 67
# ✔️ Updated link_whatsapp untuk baris 68
# ✔️ Updated template_pesan untuk baris 68
# ✔️ Updated link_whatsapp untuk baris 69
# ✔️ Updated template_pesan untuk baris 69
# ✔️ Updated link_whatsapp untuk baris 70
# ✔️ Updated template_pesan untuk baris 70
# ✔️ Updated link_whatsapp untuk baris 71
# ✔️ Updated template_pesan untuk baris 71
# ✔️ Updated link_whatsapp untuk baris 72
# ✔️ Updated template_pesan untuk baris 72
# ✔️ Updated link_whatsapp untuk baris 73
# ✔️ Updated template_pesan untuk baris 73
# ✔️ Updated link_whatsapp untuk baris 74
# ✔️ Updated template_pesan untuk baris 74
# ✔️ Updated link_whatsapp untuk baris 75
# ✔️ Updated template_pesan untuk baris 75
# ✔️ Updated link_whatsapp untuk baris 76
# ✔️ Updated template_pesan untuk baris 76
# ✔️ Updated link_whatsapp untuk baris 77
# ✔️ Updated template_pesan untuk baris 77
# ✔️ Updated link_whatsapp untuk baris 78
# ✔️ Updated template_pesan untuk baris 78
# ✔️ Updated link_whatsapp untuk baris 79
# ✔️ Updated template_pesan untuk baris 79
# ✔️ Updated link_whatsapp untuk baris 80
# ✔️ Updated template_pesan untuk baris 80
# ✔️ Updated link_whatsapp untuk baris 81
# ✔️ Updated template_pesan untuk baris 81
# ✔️ Updated link_whatsapp untuk baris 82
# ✔️ Updated template_pesan untuk baris 82
# ✔️ Updated link_whatsapp untuk baris 83
# ✔️ Updated template_pesan untuk baris 83
# ✔️ Updated link_whatsapp untuk baris 84
# ✔️ Updated template_pesan untuk baris 84
# ✔️ Updated link_whatsapp untuk baris 85
# ✔️ Updated template_pesan untuk baris 85
# ✔️ Updated link_whatsapp untuk baris 86
# ✔️ Updated template_pesan untuk baris 86
# ✔️ Updated link_whatsapp untuk baris 87
# ✔️ Updated template_pesan untuk baris 87
# ✔️ Updated link_whatsapp untuk baris 88
# ✔️ Updated template_pesan untuk baris 88
# ✔️ Updated link_whatsapp untuk baris 89
# ✔️ Updated template_pesan untuk baris 89
# ✔️ Updated link_whatsapp untuk baris 90
# ✔️ Updated template_pesan untuk baris 90
# ✔️ Updated link_whatsapp untuk baris 91
# ✔️ Updated template_pesan untuk baris 91
# ✔️ Updated link_whatsapp untuk baris 92
# ✔️ Updated template_pesan untuk baris 92
# ✔️ Updated link_whatsapp untuk baris 93
# ✔️ Updated template_pesan untuk baris 93
# ✔️ Updated link_whatsapp untuk baris 94
# ✔️ Updated template_pesan untuk baris 94
# ✔️ Updated link_whatsapp untuk baris 95
# ✔️ Updated template_pesan untuk baris 95
# ✔️ Updated link_whatsapp untuk baris 96
# ✔️ Updated template_pesan untuk baris 96
# ✔️ Updated link_whatsapp untuk baris 97
# ✔️ Updated template_pesan untuk baris 97
# ✔️ Updated link_whatsapp untuk baris 98
# ✔️ Updated template_pesan untuk baris 98
# ✔️ Updated link_whatsapp untuk baris 99
# ✔️ Updated template_pesan untuk baris 99
# ✔️ Updated link_whatsapp untuk baris 100
# ✔️ Updated template_pesan untuk baris 100
# ✔️ Updated link_whatsapp untuk baris 101
# ✔️ Updated template_pesan untuk baris 101
# ✔️ Updated link_whatsapp untuk baris 102
# ✔️ Updated template_pesan untuk baris 102
# ✔️ Updated link_whatsapp untuk baris 103
# ✔️ Updated template_pesan untuk baris 103
# ✔️ Updated link_whatsapp untuk baris 104
# ✔️ Updated template_pesan untuk baris 104
# ✔️ Updated link_whatsapp untuk baris 105
# ✔️ Updated template_pesan untuk baris 105
#
# ⛔ Error Summary:
# ❌ Error saat memproses Latifah Nur ‘Aini: Character "‘" at index 12 in text is outside the range of characters supported by the font used: "helvetica". Please consider using a Unicode font.
#
# ✅ Proses selesai!
