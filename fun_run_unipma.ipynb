# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKai7/invoice_generator/blob/main/fun_run_unipma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang diperlukan
# !pip install gspread pandas fpdf2 pyqrcode pypng requests pillow
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2

# Import library yang dibutuhkan
import gspread
from google.colab import auth
from google.auth import default
import pandas as pd
from fpdf import FPDF
import os
from google.colab import drive
from datetime import datetime
import requests
from io import BytesIO
from PIL import Image
import urllib.parse
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Autentikasi Google Colab dengan Google Sheets & Drive
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Inisialisasi Google Drive API
drive_service = build('drive', 'v3', credentials=creds)

# Mount Google Drive untuk menyimpan invoice
drive.mount('/content/drive')

# Buka spreadsheet
spreadsheet_url = "https://docs.google.com/spreadsheets/d/12C-jDb_1_w6N4DdccOmjg2rshGE3F1Q08xQOcEP0NrI/edit?gid=0#gid=0"
sh = gc.open_by_url(spreadsheet_url)
worksheet = sh.get_worksheet(0)

# Ambil semua data dan periksa kolom yang tersedia
expected_headers = ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
records = worksheet.get_all_records(expected_headers=expected_headers)
df = pd.DataFrame.from_records(records)


# Periksa nama kolom yang sebenarnya
print("Kolom yang tersedia di spreadsheet:")
print(df.columns.tolist())

# Pastikan nama kolom sesuai dengan spreadsheet Anda
COLUMN_MAPPING = {
    'invoice_id': 'KODE_INVOICE',
    'name': 'NAMA',
    'category': 'KATEGORI',
    'barcode': 'BARCODE',
    'whatsapp': 'NO_WA',
    'address': 'ALAMAT'
}

# Path logo di Google Drive (sesuaikan dengan path Anda)
LOGO_DIES_PATH = '/content/drive/MyDrive/logo/diesnatalis 1-01.png'  # Ganti dengan path yang benar
LOGO_UNIPMA_PATH = '/content/drive/MyDrive/logo/Unipma.png'  # Ganti dengan path yang benar

class InvoicePDF(FPDF):
    def __init__(self, participant_data):
        super().__init__(format='A4', orientation='L')  # A4 Landscape
        self.participant_data = participant_data
        self.add_page()

    def header(self):
        # Tambahkan background dengan efek fade
        self._add_faded_background()

        # Tambahkan logo jika file ada
        try:
            # Logo Dies Natalis di kiri - ukuran disesuaikan
            if os.path.exists(LOGO_UNIPMA_PATH):
                self.image(LOGO_UNIPMA_PATH, x=15, y=15, w=30)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading UNIPMA logo: {e}")

        try:
            # Logo UNIPMA di kanan - ukuran disesuaikan
            if os.path.exists(LOGO_DIES_PATH):
                self.image(LOGO_DIES_PATH, x=210, y=0, w=100)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading Dies Natalis logo: {e}")

        # Judul
        self.set_y(25)
        self.set_font('Arial', 'B', 18)
        self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
        self.set_font('Arial', 'I', 12)
        self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
        self.ln(5)

    def _add_faded_background(self):
        # Path ke gambar background (sesuaikan dengan path Anda)
        BG_IMAGE_PATH = '/content/drive/MyDrive/logo/asset diesnat fun run/bg1.jpg'  # Ganti dengan path gambar background Anda

        if os.path.exists(BG_IMAGE_PATH):
            try:
                # Simpan posisi Y saat ini
                current_y = self.get_y()

                # Geser gambar 20px ke kiri (nilai negatif) dan perluas lebar untuk menutupi area yang kosong
                x_offset = -15  # Sesuaikan nilai ini untuk mengatur seberapa jauh ke kiri
                adjusted_width = self.w + abs(x_offset)  # Tambahkan lebar untuk kompensasi pergeseran

                # Tambahkan gambar background dengan opacity rendah
                self.image(BG_IMAGE_PATH, x=x_offset, y=0, w=adjusted_width, h=self.h)

                # Tambahkan layer semi-transparan untuk efek fade
                self.set_fill_color(255, 255, 255, 200)  # Putih dengan alpha 200/255 (~78% opacity)
                self.rect(0, 0, self.w, self.h, style='F')

                # Kembalikan posisi Y
                self.set_y(current_y)
            except Exception as e:
                print(f"⚠️ Error adding background: {e}")
        else:
            print("⚠️ Background image not found, skipping...")

    def footer(self):
        # Thank you message di bagian footer tengah
        self.set_y(-15)
        self.set_font('Arial', 'I', 12)
        self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')

    def create_invoice(self):
        # Informasi invoice
        self.set_font('Arial', 'B', 14)
        self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')

        # Tanggal
        self.set_font('Arial', '', 11)
        self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
        self.ln(8)

        # Garis pemisah
        self.line(10, self.get_y(), 287, self.get_y())
        self.ln(10)

        # Layout 3 kolom dengan alignment yang presisi
        col_width = 85
        start_y = self.get_y()  # Simpan posisi Y awal

        # Kolom 1: Data peserta
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
        self.set_font('Arial', '', 11)

        # Simpan posisi Y untuk alignment
        y_details = self.get_y()

        # Initialize name_y at the beginning
        name_y = y_details

        # Nama (baseline untuk alignment)
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Nama:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
        self.ln(2)
        name_y = self.get_y()

        # WhatsApp jika ada
        if COLUMN_MAPPING["whatsapp"] in self.participant_data and self.participant_data[COLUMN_MAPPING["whatsapp"]]:
            whatsapp_num = str(self.participant_data[COLUMN_MAPPING["whatsapp"]])
            clean_number = ''.join(filter(str.isdigit, whatsapp_num))
            if clean_number.startswith('0'):
                clean_number = '+62' + clean_number[1:]
            elif not clean_number.startswith('62'):
                clean_number = '+62' + clean_number
            else:
                clean_number = '+' + clean_number

            self.set_font('Arial', 'B', 11)
            self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
            self.set_font('Arial', '', 11)
            self.cell(col_width, 6, clean_number, ln=1, align='L')
            self.ln(2)

        # Alamat jika ada
        if COLUMN_MAPPING["address"] in self.participant_data:
            address = self.participant_data[COLUMN_MAPPING["address"]]
            if pd.notna(address) and str(address).strip() != '':
                self.set_font('Arial', 'B', 11)
                self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
                self.set_font('Arial', '', 11)
                self.multi_cell(col_width, 6, str(address), align='L')
                self.ln(2)

        # Kategori
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
        self.ln(2)

        # Kolom 2: Detail pengambilan race pack (tengah)
        self.set_xy(120, y_details - 5)  # Sejajar dengan "PARTICIPANT DETAILS"
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')

        # Posisikan konten race pack sejajar dengan "Name" di X=100
        self.set_xy(100, name_y - 10)  # X=100, Y sejajar dengan "Name"
        self.set_font('Arial', '', 11)

        # Format lengkap dengan indentasi yang tepat
        race_pack_content = [
          ("Tanggal:", 0),                     # Header - no indent
          ("- 30 Mei 2025", 0),                # Date 1 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-16.00", 10),       # Session 2 - indent 10
          ("- 31 Mei 2025", 0),                # Date 2 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-15.00", 10),       # Session 2 - indent 10
          ("", 0),                             # Empty line
          ("Lokasi:", 0),                      # Location header - no indent
          ("Laboratorium Terpadu UNIPMA", 0)   # Location - no indent
        ]

        # Cetak dengan indentasi yang konsisten
        for line, indent in race_pack_content:
            self.set_x(120 + indent)
            self.cell(col_width - indent, 6, line, ln=1, align='L')

        # Kolom 3: Barcode/QR code
        if COLUMN_MAPPING["barcode"] in self.participant_data and self.participant_data[COLUMN_MAPPING["barcode"]]:
            try:
                response = requests.get(self.participant_data[COLUMN_MAPPING["barcode"]])
                img = Image.open(BytesIO(response.content))

                temp_img_path = f"/tmp/barcode_{self.participant_data[COLUMN_MAPPING['invoice_id']]}.png"
                img.save(temp_img_path)

                # Posisi di kolom kanan, sejajar dengan "Name"
                x_position = 220
                y_position = name_y - 15  # Adjust to align with "Name"

                self.image(temp_img_path, x=x_position, y=y_position, w=60)

                # Teks di bawah barcode
                self.set_xy(x_position, y_position + 56)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')

                # Teks di bawah barcode 2
                self.set_xy(x_position, y_position + 61)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')

                os.remove(temp_img_path)
            except Exception as e:
                print(f"⚠️ Error adding barcode: {e}")

        # Notes di bagian bawah - diposisikan lebih tinggi
        notes_y = max(self.get_y() + 1, 120)  # Mengurangi 15pt dari posisi sebelumnya
        self.set_xy(10, notes_y)
        self.set_font('Arial', 'I', 11)
        notes = [
            "Catatan:",
            "- Harap datang tepat waktu sesuai sesi yang dipilih",
            "- Tunjukkan barcode ini saat pengambilan race pack",
            "- Bawa identitas yang valid (KTP/SIM/KTM/KARTU PELAJAR)"
        ]
        for note in notes:
            self.cell(0, 6, note, ln=1, align='L')

def generate_invoice_pdf(participant_data):
    # Buat PDF
    pdf = InvoicePDF(participant_data)
    pdf.create_invoice()

    # Buat folder penyimpanan di Colab
    local_invoice_dir = "/content/invoices"
    os.makedirs(local_invoice_dir, exist_ok=True)

    # Simpan PDF lokal
    pdf_filename = f"FUN RUN UNIPMA_{participant_data[COLUMN_MAPPING['invoice_id']]}.pdf"
    local_pdf_path = f"{local_invoice_dir}/{pdf_filename}"
    pdf.output(local_pdf_path)

    return local_pdf_path, pdf_filename

def upload_to_drive(file_path, file_name, folder_id=None):
    """Upload file ke Google Drive dan set permissions"""
    file_metadata = {
        'name': file_name,
        'parents': [folder_id] if folder_id else None
    }

    media = MediaFileUpload(file_path, mimetype='application/pdf')

    file = drive_service.files().create(
        body=file_metadata,
        media_body=media,
        fields='id,webViewLink'
    ).execute()

    # Set permissions agar bisa diakses oleh siapa saja dengan link
    permission = {
        'type': 'anyone',
        'role': 'reader'
    }

    drive_service.permissions().create(
        fileId=file['id'],
        body=permission
    ).execute()

    return file['webViewLink']

def generate_whatsapp_link(phone_number):
    if pd.isna(phone_number) or not phone_number:
        return ""

    # Format nomor WhatsApp (62XXXXXXXXXX)
    clean_number = ''.join(filter(str.isdigit, str(phone_number)))
    if clean_number.startswith('0'):
        clean_number = '62' + clean_number[1:]
    elif not clean_number.startswith('62'):
        clean_number = '62' + clean_number
    return f"https://wa.me/{clean_number}"

def generate_message_template(participant_data, drive_link):
    # Format WhatsApp number dengan +62
    whatsapp_num = str(participant_data.get(COLUMN_MAPPING['whatsapp'], ''))
    if whatsapp_num:
        clean_number = ''.join(filter(str.isdigit, whatsapp_num))
        if clean_number.startswith('0'):
            clean_number = '+62' + clean_number[1:]
        elif not clean_number.startswith('62'):
            clean_number = '+62' + clean_number
        else:
            clean_number = '+' + clean_number
    else:
        clean_number = ''

    return f"""
Halo {participant_data[COLUMN_MAPPING['name']]},

Terima kasih telah mendaftar di *UNIPMA FUN RUN 5K 2025*!
Berikut invoice resmi Anda:

🔹 *Kode Invoice:* {participant_data[COLUMN_MAPPING['invoice_id']]}
🔹 *Kategori:* {participant_data[COLUMN_MAPPING['category']]}
🔹 *Alamat:* {participant_data[COLUMN_MAPPING['address']]}


📥 *Download Invoice:*
{drive_link}

*Info Pengambilan Race Pack:*
📅 *Tanggal:*
- 30 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-16.00)
- 31 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-15.00)
🏫 *Lokasi:* Laboratorium Terpadu UNIPMA

*Catatan:*
- Harap datang tepat waktu sesuai sesi yang dipilih
- Tunjukkan barcode yang ada pada invoice saat pengambilan racepack
- Bawa identitas yang valid(KTP/SIM/KTM/KARTU PELAJAR)

Mohon simpan invoice ini sebagai bukti pendaftaran.
Jika ada pertanyaan, hubungi kami via WhatsApp.

Salam,
*Panitia Unipma Fun Run 5K 2025*
"""

def process_all_participants():
    updates = []
    errors = []

    # ID folder tujuan di Google Drive (ganti dengan folder ID Anda)
    DRIVE_FOLDER_ID = '1A8ADXVlMOHPJsBhvaxZuBjL7egO3Wq2_'  # Ganti dengan folder ID tujuan

    for index, row in df.iterrows():
        try:
            invoice_id = row[COLUMN_MAPPING['invoice_id']]
            print(f"\nMemproses peserta: {row.get(COLUMN_MAPPING['name'], '')} (Invoice: {invoice_id})")

            # 1. Generate PDF
            local_pdf_path, pdf_filename = generate_invoice_pdf(row)

            # 2. Upload ke Google Drive dan dapatkan link
            drive_link = upload_to_drive(local_pdf_path, pdf_filename, DRIVE_FOLDER_ID)
            print(f"✅ Invoice diupload ke: {drive_link}")

            # 3. Generate link WhatsApp
            whatsapp_link = generate_whatsapp_link(row.get(COLUMN_MAPPING['whatsapp'], ''))
            updates.append((index, 'link_whatsapp', whatsapp_link))

            # 4. Buat template pesan
            message = generate_message_template(row, drive_link)
            updates.append((index, 'template_pesan', message))

            # 5. Bersihkan file lokal
            os.remove(local_pdf_path)

        except Exception as e:
            error_msg = f"❌ Error saat memproses {row.get(COLUMN_MAPPING['name'], '')}: {str(e)}"
            print(error_msg)
            errors.append((index, error_msg))

    # Update spreadsheet
    for update in updates:
        row_idx, col_name, value = update
        try:
            # Cari kolom yang sesuai
            col_names = [col.lower() for col in df.columns]
            target_col = col_name.lower()

            if target_col in col_names:
                col_idx = col_names.index(target_col) + 1  # +1 karena indeks spreadsheet mulai dari 1
                worksheet.update_cell(row_idx + 2, col_idx, value)
                print(f"✔️ Updated {col_name} untuk baris {row_idx + 2}")
            else:
                print(f"⚠️ Kolom {col_name} tidak ditemukan di spreadsheet")
        except Exception as e:
            print(f"❌ Gagal mengupdate spreadsheet untuk baris {row_idx}: {str(e)}")

    # Tampilkan error summary
    if errors:
        print("\n⛔ Error Summary:")
        for error in errors:
            print(error[1])

# Jalankan proses utama
process_all_participants()
print("\n✅ Proses selesai!")
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.11/dist-packages (6.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting fpdf2
#   Downloading fpdf2-2.8.3-py2.py3-none-any.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 1.2 MB/s eta 0:00:00
# Collecting pyqrcode
#   Downloading PyQRCode-1.2.1.zip (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pypng
#   Downloading pypng-0.20220715.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from gspread) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gspread) (1.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (4.58.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Downloading fpdf2-2.8.3-py2.py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.7/245.7 kB 5.1 MB/s eta 0:00:00
# Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 1.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyqrcode
#   Building wheel for pyqrcode (setup.py) ... done
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36222 sha256=e79030204970e192711a4b97183d75326a406df3541468b632b7e518ec45145c
#   Stored in directory: /root/.cache/pip/wheels/f5/db/22/ade11e0c0854d1bb2fcc673dc90f6495ee2c0d2b6eb41492e3
# Successfully built pyqrcode
# Installing collected packages: pyqrcode, pypng, fpdf2
# Successfully installed fpdf2-2.8.3 pypng-0.20220715.0 pyqrcode-1.2.1
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.38.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.4.26)
# Mounted at /content/drive
# Kolom yang tersedia di spreadsheet:
# ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
#
# Memproses peserta: GANES FAHREZI M  (Invoice: GAN-1-3981)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# <ipython-input-1-04c08513ebf0>:88: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 18)
# <ipython-input-1-04c08513ebf0>:89: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
# <ipython-input-1-04c08513ebf0>:90: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-1-04c08513ebf0>:91: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
# <ipython-input-1-04c08513ebf0>:129: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 14)
# <ipython-input-1-04c08513ebf0>:130: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')
# <ipython-input-1-04c08513ebf0>:133: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:134: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
# <ipython-input-1-04c08513ebf0>:146: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-1-04c08513ebf0>:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
# <ipython-input-1-04c08513ebf0>:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:157: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-1-04c08513ebf0>:158: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Nama:', ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:159: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:160: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:175: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-1-04c08513ebf0>:176: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:177: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:178: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, clean_number, ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:185: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-1-04c08513ebf0>:186: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:187: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:192: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-1-04c08513ebf0>:193: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:194: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:195: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:200: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-1-04c08513ebf0>:201: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')
# <ipython-input-1-04c08513ebf0>:205: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-1-04c08513ebf0>:224: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width - indent, 6, line, ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:243: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-1-04c08513ebf0>:244: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')
# <ipython-input-1-04c08513ebf0>:248: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-1-04c08513ebf0>:249: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')
# <ipython-input-1-04c08513ebf0>:258: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 11)
# <ipython-input-1-04c08513ebf0>:266: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 6, note, ln=1, align='L')
# <ipython-input-1-04c08513ebf0>:124: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-1-04c08513ebf0>:125: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=0 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Ddzkl8BTaswCK40TGaUcerrTi3nNg7L7/view?usp=drivesdk
#
# Memproses peserta: RIFKY NANDYA PRADIPTA  (Invoice: RIF-1-9676)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vl7e5URJMeSdYGV1nYcWDsIEoUuy_FE4/view?usp=drivesdk
#
# Memproses peserta: Aldino Revi Brilliantara  (Invoice: ALD-1-9828)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1dib3_GStJ6dHIiIfMu0uIoXc6E4zHktS/view?usp=drivesdk
#
# Memproses peserta: Naura Firda Durratul Syifa  (Invoice: NAU-1-6991)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Ffc1HvYRc-J-HTmhd2mpcpr1-lN1KcwR/view?usp=drivesdk
#
# Memproses peserta: Navylian Almaghfira Yashinta (Invoice: NAV-1-8380)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1lchVdWOv8jrjOwwko-BIVtNHQBZUESSo/view?usp=drivesdk
#
# Memproses peserta: Muhamad Shafiq Rifai (Invoice: MUH-1-8680)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RUch4Tkg1LhKC0uaqYZdHjhLaznO6Ay2/view?usp=drivesdk
#
# Memproses peserta: Elang Tirta Pratama (Invoice: ELA-1-7467)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TsVx7lvzveKjcYdePhMvs9zIWnTQ263p/view?usp=drivesdk
#
# Memproses peserta: Asar Purbaya (Invoice: ASA-1-4204)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1AQIL7KX8Z7wz6MdDWR75JYl2MtTwW1rm/view?usp=drivesdk
#
# Memproses peserta: randi ramadhan (Invoice: RAN-1-3881)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1hYY_wsxr-OwqQwxSMf9R_dpx-AX0D2Xs/view?usp=drivesdk
#
# Memproses peserta: Zhadhat Sayyidatina Al Aisyah (Invoice: ZHA-1-4710)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cWWHOnyXueAh1dZgq6N-u3WFmgooXBUl/view?usp=drivesdk
#
# Memproses peserta: CALVIN ASVINO PUTRA (Invoice: CAL-1-3991)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TXaengtdDbu2-KsKlm9F5UtDdx-LbN4E/view?usp=drivesdk
#
# Memproses peserta: Frendy Wicaksana Putra  (Invoice: FRE-1-0055)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1-V7LIrTeNGUJTzW9Z2v3Gz8INeqZBT46/view?usp=drivesdk
#
# Memproses peserta: ALFIRA DEWI SRI TANJUNG (Invoice: ALF-1-3773)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1HCPesi_o7GQeTpDuFxudIvh_tzF3Z2KL/view?usp=drivesdk
#
# Memproses peserta: REVAN NAUFAL AYUDYA HANASTA  (Invoice: REV-1-8907)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1dzSHgJd_0cplldt8_1kKD8epKSpgaB8X/view?usp=drivesdk
#
# Memproses peserta: berlian astyana puri (Invoice: BER-1-8552)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1EUsbgPg2fUwGb0q1aCuFcshCw_ZKx5UE/view?usp=drivesdk
#
# Memproses peserta: Oktafia Difa Azahra (Invoice: OKT-1-4980)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1YWw1NWuH-eHsKj34_LMnI8Ww6OK2wOlY/view?usp=drivesdk
#
# Memproses peserta: Nuning Irmana Fidiani (Invoice: NUN-1-1989)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1GsvN6W3tS68cTUMsw5hLNWGXzse1PUl7/view?usp=drivesdk
#
# Memproses peserta: RYANDRA IRSYADHI BRAMANTYO (Invoice: RYA-1-0160)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1M_1MndAfE6dkG2qFmZ9-WcDm9Z4BKOgw/view?usp=drivesdk
#
# Memproses peserta: Farras Alya Suryawan (Invoice: FAR-1-4620)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1bxJr9B1PrTNNCti_c7FRHryItOFOko1g/view?usp=drivesdk
#
# Memproses peserta: ALIFIA NAVISA ZAHRA (Invoice: ALI-1-1343)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OU-FXLRPjDpQgDOspb4ChMrLfxYwLo7f/view?usp=drivesdk
#
# Memproses peserta: valian maulana agung (Invoice: VAL-1-6187)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1v2la3mdn0G1eRrxKH3ifjk9mgujRht5o/view?usp=drivesdk
#
# Memproses peserta: Moch hafidz wasilurrohman (Invoice: MOC-1-3620)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mizeZzauT9eUszXtIXLcJR1S_YXWxfoY/view?usp=drivesdk
#
# Memproses peserta: Rayhan Mandala Cakti (Invoice: RAY-1-9742)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1l5i4LuqEj8OqEtH67NFEwXt9yrFSrplk/view?usp=drivesdk
#
# Memproses peserta: Rival Diano (Invoice: RIV-1-1484)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1KdWlBu5anEqfENn-dylxjKOOk6GEQ1SE/view?usp=drivesdk
#
# Memproses peserta: CINTHYA PUTRI FRANSISCA (Invoice: CIN-1-5529)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ke3rXWKF7WmTBXqKpP1NBzcyj_DEVMK6/view?usp=drivesdk
#
# Memproses peserta: Aida Irsalina Muntazar  (Invoice: AID-1-6550)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1HQJ38amwYhScNEjRfd8esQ8PQWsHu7Fn/view?usp=drivesdk
#
# Memproses peserta: Fahri Akbar Nugraha (Invoice: FAH-1-9543)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cbDiKLXl1VYyCAVm_uZ8SvA_DlE0yEs_/view?usp=drivesdk
#
# Memproses peserta: Elizabeth Nadiva Rahma (Invoice: ELI-1-3367)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1lmsMji0Z_CN0TkhOLEszp7PxKKZ6jIpx/view?usp=drivesdk
#
# Memproses peserta: Misbahul mujib (Invoice: MIS-1-3185)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1oYythMISVpCjlkYZo9hluMVbC3QHZCJJ/view?usp=drivesdk
#
# Memproses peserta: NAFIS NAJWAN AZIZ (Invoice: NAF-1-0561)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ZH97VGuX5e7CjgR9peZh7lTNI8uMDdoO/view?usp=drivesdk
#
# Memproses peserta: SAKA NUR RACHMADI (Invoice: SAK-1-1086)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ojSCF6-_hTK9lNkrlTY7NE4838oaV9B1/view?usp=drivesdk
#
# Memproses peserta: DINDA LILA BENADETA (Invoice: DIN-1-2680)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1hKBaN_kK-ifh6NhD8y1do9P2_ve4D5eT/view?usp=drivesdk
#
# Memproses peserta: Naufal Hafidz Candra (Invoice: NAU-1-7585)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1W-8ybfkihScrw1kP13y_a5WqA-bFpegQ/view?usp=drivesdk
#
# Memproses peserta: Alwan Daffa El Haqqi (Invoice: ALW-1-6011)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1JNcnaUe1uJeFL3tx-Q7KIKARFou2tMVy/view?usp=drivesdk
#
# Memproses peserta: rois septi aulia (Invoice: ROI-1-4502)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OBTCHk8Aasm2eWVDnTCa9TNc3AHJkHKL/view?usp=drivesdk
#
# Memproses peserta: Deffi Eka Wijayanti (Invoice: DEF-1-1981)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1yCWoANt8Uscx6m7JogFdbFlw6x6_D3ga/view?usp=drivesdk
#
# Memproses peserta: AZWA IZADENT KHAFZA’I (Invoice: AZW-1-3729)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ❌ Error saat memproses AZWA IZADENT KHAFZA’I: Character "’" at index 19 in text is outside the range of characters supported by the font used: "helvetica". Please consider using a Unicode font.
#
# Memproses peserta: Linggar pramesti studyninglias (Invoice: LIN-1-4879)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1GtjbOXRADl6iPWirpKUUWl5XUO_g9vTN/view?usp=drivesdk
#
# Memproses peserta: Eka Noviansyah Hermawan (Invoice: EKA-1-0499)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ilBVU96uq7v1xb3WD9XG2J7PdIaLDTEg/view?usp=drivesdk
#
# Memproses peserta: Muhammad Bisma Bani oktabian  (Invoice: MUH-1-5700)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/17N7Td3GRL92N5GkP6XNDLnAE1EJgJhgy/view?usp=drivesdk
#
# Memproses peserta: YANUAR HENDRAWAN  (Invoice: YAN-1-4279)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zorIxnRnFNS3BmnV9y2z1QxA2SSlZhRr/view?usp=drivesdk
#
# Memproses peserta: Talitha Azmi Fathonah  (Invoice: TAL-1-3812)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RzPHDfd1U-XsNvPBJdKg9CZrVXo8-vLN/view?usp=drivesdk
#
# Memproses peserta: Masyudiansyah (Invoice: MAS-1-0392)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mgURfvRsozgMKskPQimZ_mg58MErw04a/view?usp=drivesdk
#
# Memproses peserta: Azza Habibullah (Invoice: AZZ-1-9939)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1oBW44fDlcIUasAL-2_W8NSGF9sdiRSwd/view?usp=drivesdk
#
# Memproses peserta: RICO ALVIANO (Invoice: RIC-1-6195)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_cYKSCHR4eeHF_MwUGt4UrfIePLEBtWJ/view?usp=drivesdk
#
# Memproses peserta: Ferdyan Putra Setiawan (Invoice: FER-1-5969)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zER-feS8OZINhW0Ot4mESEcUNDtVlioE/view?usp=drivesdk
#
# Memproses peserta: ALYA HASHIFA RAHAYU (Invoice: ALY-1-3023)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1r05_vbAB89JpfwOHNxCnJCi9i_94Y13w/view?usp=drivesdk
#
# Memproses peserta: yuma yeshaya abid jones  (Invoice: YUM-1-3400)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Ka6QsNq3IIDLXtoOLlosckUm3Q126XvR/view?usp=drivesdk
#
# Memproses peserta: Faishol hidayat (Invoice: FAI-1-0909)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1yTU_z8ACz2MU9-R18tYfLvrjAD4ozG10/view?usp=drivesdk
#
# Memproses peserta: Septi Melani Putri  (Invoice: SEP-1-0321)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xYE2Z5tNeb8WE7IQYaESOAPqDMpkVkUH/view?usp=drivesdk
#
# Memproses peserta: Luhur Sekhuti (Invoice: LUH-1-0666)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1UP9MowxgbyUFYRlO9V5v8Zlt-FSTmcaa/view?usp=drivesdk
#
# Memproses peserta: CANTIKA NINELY MURAYA  NANDINANTI.  (Invoice: CAN-1-3052)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1yRv3M3vwr30JEynV-2y1Qgies7U_4Y5H/view?usp=drivesdk
#
# Memproses peserta: AVRILLIA YULIANSHI (Invoice: AVR-1-9477)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1kZ8hxLFAPnGfb5uGnbcQVTeq8_gsji-s/view?usp=drivesdk
#
# Memproses peserta: SATRIYA FAIZ RAMADHAN (Invoice: SAT-1-7261)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ceKoMB2UzvtYduyXi8DEMtxsSonjih-x/view?usp=drivesdk
#
# Memproses peserta: SYAMIL AHMAD KADAFI (Invoice: SYA-1-9477)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1svLcWngYIefZhf-KlkpcKr5D8QP89dPi/view?usp=drivesdk
#
# Memproses peserta: Dwi Trisnawati Zainal (Invoice: DWI-1-2009)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1rlYgzAYwXPv6tPidBM7SixdI1Uocl5MZ/view?usp=drivesdk
#
# Memproses peserta: MOHAMMAD REILDA TWO FRIDAY (Invoice: MOH-1-9984)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1snSg1O7-CvZRgzkxgFDwnKlbYsvEWJe3/view?usp=drivesdk
#
# Memproses peserta: MUHAMMAD AFFAN FADILLAH (Invoice: MUH-1-4728)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1DRnmSmTSnOQEGjxyc-Sf9L4gpjH_H94r/view?usp=drivesdk
#
# Memproses peserta: Anang Setiyawan (Invoice: ANA-1-9666)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ndhU5ChL830tOUzpZMKR1AzWaThUlGyv/view?usp=drivesdk
#
# Memproses peserta: Sekar Surya Putri  (Invoice: SEK-1-6551)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1k4ElICxwv9RA5Wee8LB0WxMBcUDxCiwh/view?usp=drivesdk
#
# Memproses peserta: Ananda Prasetya Putri (Invoice: ANA-1-8792)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Xnks3Cf8S99kYQidxoMFQ3uKyXXcSL9c/view?usp=drivesdk
#
# Memproses peserta: REYHAN FADILLAH (Invoice: REY-1-5075)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Nx3bGbCo-vrZMarcDmr__iLCg_MHLsLF/view?usp=drivesdk
#
# Memproses peserta: Amalia As-Sholihah Rahmawati   (Invoice: AMA-1-3725)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cpD_S2nOrMffv9cc-K-J_N2ictgyVagG/view?usp=drivesdk
#
# Memproses peserta: Fiqi Yoga Pratama putra  (Invoice: FIQ-1-1240)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/110N6Y1NcKilFGB648TSoaRpQnI_ZsXtP/view?usp=drivesdk
#
# Memproses peserta: ALIFVIAN RAMADHANI (Invoice: ALI-1-9732)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1z0zoVhaIbXtbmgy1Y_AQ5tQG-y6nykMp/view?usp=drivesdk
#
# Memproses peserta: Ichlaussal Abyan (Invoice: ICH-1-9576)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ZZb88x7w3EKG8leUa0LLYkTjkXkempl0/view?usp=drivesdk
#
# Memproses peserta: AFGAN NURFAHREZY (Invoice: AFG-1-4419)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1u9LHWheP1efFC-OkpZp-xQegfQPUa0yV/view?usp=drivesdk
#
# Memproses peserta: MIFIAN ZUHAL (Invoice: MIF-1-5065)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vyCmMA4VId2ynpZEF9CLfws-NDN5jfoQ/view?usp=drivesdk
#
# Memproses peserta: Afnan nurfahrezy  (Invoice: AFN-1-9719)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/14oQJtFrYkerOMvbbAZ1-Kf3fPmFvlWeS/view?usp=drivesdk
#
# Memproses peserta: Rifai Ahsana  (Invoice: RIF-1-8843)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1VESE3bzy1d0CVUC-7jd6anCq7-_g6kuH/view?usp=drivesdk
#
# Memproses peserta: AMJAD NURIL  (Invoice: AMJ-1-6565)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10ypYMT3bsicfWiM5-a6o2REh2DAB30fU/view?usp=drivesdk
#
# Memproses peserta: NABILA ANNASTASYA  (Invoice: NAB-1-4264)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1B6l_eF-olicPBOC_3m1RSsLoo-gFP9Do/view?usp=drivesdk
#
# Memproses peserta: Prasetya Indarto (Invoice: PRA-1-0108)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1KElF5UsXZ9Qd0cL1LOSTdTS3t9oea2di/view?usp=drivesdk
#
# Memproses peserta: Alzena Atha Sadiya (Invoice: ALZ-1-7471)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vExCiNpDS2vYsET5vO599PnFhgoQBu6u/view?usp=drivesdk
#
# Memproses peserta: Muhammad Afif Fairuz (Invoice: MUH-1-4849)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1B5RieIrjtLwvDCH84Q889qHuNXqtUkV7/view?usp=drivesdk
#
# Memproses peserta: NOVA LISA KARISMAWATI (Invoice: NOV-1-0089)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1f8AC2Bs7e4kx-haS-TGYhdiYyvsWcmdk/view?usp=drivesdk
#
# Memproses peserta: JAUZA' TUHFATUSSALMA (Invoice: JAU-1-5932)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13qwrpW00z-wKT-ZxRRGrlLaAeSD1Zdzv/view?usp=drivesdk
#
# Memproses peserta: Arshena Nizzar Asy Syakiri (Invoice: ARS-1-7808)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1c1Y2QyNPYCT3wxT2blEzlcZdADFnz7Br/view?usp=drivesdk
#
# Memproses peserta: Alwan Faiz Naufal (Invoice: ALW-1-2506)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xbHd_HWZfvVhavVPjLVtEXZ6zjFiS79D/view?usp=drivesdk
#
# Memproses peserta: ALIF RIZKI ASHSHIDDIQ (Invoice: ALI-1-9396)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/12TlFCuKQoqLeaZJreRNrIrBmkis8sRgu/view?usp=drivesdk
#
# Memproses peserta: GESANG PRASETYA PUTRA (Invoice: GES-1-4376)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1EoxdbHFrPPE96--R428hQbgY8MNgr-yZ/view?usp=drivesdk
#
# Memproses peserta: Ahmad Za'im Muzakki (Invoice: AHM-1-1704)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Axm5ZW1fhwpm6URZ5dc1KfzCWjxnO87o/view?usp=drivesdk
#
# Memproses peserta: RIDWAN RAHMADANI (Invoice: RID-1-3527)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11X5Fvm_SkYUTAFQ_SOSxieAama_nJGpP/view?usp=drivesdk
#
# Memproses peserta: HENDRA MUSHTOFA MUZAMMIL WAFY (Invoice: HEN-1-9628)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OXRceqGVqT9uALvEXTy3V-Xj7iJDqWaW/view?usp=drivesdk
#
# Memproses peserta: Moh Irham (Invoice: MOH-1-5551)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jK48ZRJSjjLuygYBcr9_YJVsOF00tuth/view?usp=drivesdk
#
# Memproses peserta: Choirul Anwar (Invoice: CHO-1-9542)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/18oUVSlMIyNzKrVFACrtRhBzqSjcO5-IX/view?usp=drivesdk
#
# Memproses peserta: Nur Zahid Akbar Maulana  (Invoice: NUR-1-9106)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TsFI748gAY7rT3bFTGbTsTLVq_eXMqBJ/view?usp=drivesdk
#
# Memproses peserta: Sunarni (Invoice: SUN-1-5454)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MpEGIIrhsydrrrwxWNjwRKgUS_HuZco1/view?usp=drivesdk
#
# Memproses peserta: Muhammad Haris Eka Saputra (Invoice: MUH-1-8560)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/195lCoGC5cvNWSOqgnfcSs7s3wlymZpPm/view?usp=drivesdk
# ✔️ Updated link_whatsapp untuk baris 2
# ✔️ Updated template_pesan untuk baris 2
# ✔️ Updated link_whatsapp untuk baris 3
# ✔️ Updated template_pesan untuk baris 3
# ✔️ Updated link_whatsapp untuk baris 4
# ✔️ Updated template_pesan untuk baris 4
# ✔️ Updated link_whatsapp untuk baris 5
# ✔️ Updated template_pesan untuk baris 5
# ✔️ Updated link_whatsapp untuk baris 6
# ✔️ Updated template_pesan untuk baris 6
# ✔️ Updated link_whatsapp untuk baris 7
# ✔️ Updated template_pesan untuk baris 7
# ✔️ Updated link_whatsapp untuk baris 8
# ✔️ Updated template_pesan untuk baris 8
# ✔️ Updated link_whatsapp untuk baris 9
# ✔️ Updated template_pesan untuk baris 9
# ✔️ Updated link_whatsapp untuk baris 10
# ✔️ Updated template_pesan untuk baris 10
# ✔️ Updated link_whatsapp untuk baris 11
# ✔️ Updated template_pesan untuk baris 11
# ✔️ Updated link_whatsapp untuk baris 12
# ✔️ Updated template_pesan untuk baris 12
# ✔️ Updated link_whatsapp untuk baris 13
# ✔️ Updated template_pesan untuk baris 13
# ✔️ Updated link_whatsapp untuk baris 14
# ✔️ Updated template_pesan untuk baris 14
# ✔️ Updated link_whatsapp untuk baris 15
# ✔️ Updated template_pesan untuk baris 15
# ✔️ Updated link_whatsapp untuk baris 16
# ✔️ Updated template_pesan untuk baris 16
# ✔️ Updated link_whatsapp untuk baris 17
# ✔️ Updated template_pesan untuk baris 17
# ✔️ Updated link_whatsapp untuk baris 18
# ✔️ Updated template_pesan untuk baris 18
# ✔️ Updated link_whatsapp untuk baris 19
# ✔️ Updated template_pesan untuk baris 19
# ✔️ Updated link_whatsapp untuk baris 20
# ✔️ Updated template_pesan untuk baris 20
# ✔️ Updated link_whatsapp untuk baris 21
# ✔️ Updated template_pesan untuk baris 21
# ✔️ Updated link_whatsapp untuk baris 22
# ✔️ Updated template_pesan untuk baris 22
# ✔️ Updated link_whatsapp untuk baris 23
# ✔️ Updated template_pesan untuk baris 23
# ✔️ Updated link_whatsapp untuk baris 24
# ✔️ Updated template_pesan untuk baris 24
# ✔️ Updated link_whatsapp untuk baris 25
# ✔️ Updated template_pesan untuk baris 25
# ✔️ Updated link_whatsapp untuk baris 26
# ✔️ Updated template_pesan untuk baris 26
# ✔️ Updated link_whatsapp untuk baris 27
# ✔️ Updated template_pesan untuk baris 27
# ✔️ Updated link_whatsapp untuk baris 28
# ✔️ Updated template_pesan untuk baris 28
# ✔️ Updated link_whatsapp untuk baris 29
# ✔️ Updated template_pesan untuk baris 29
# ✔️ Updated link_whatsapp untuk baris 30
# ✔️ Updated template_pesan untuk baris 30
# ✔️ Updated link_whatsapp untuk baris 31
# ✔️ Updated template_pesan untuk baris 31
# ✔️ Updated link_whatsapp untuk baris 32
# ✔️ Updated template_pesan untuk baris 32
# ✔️ Updated link_whatsapp untuk baris 33
# ✔️ Updated template_pesan untuk baris 33
# ✔️ Updated link_whatsapp untuk baris 34
# ✔️ Updated template_pesan untuk baris 34
# ✔️ Updated link_whatsapp untuk baris 35
# ✔️ Updated template_pesan untuk baris 35
# ✔️ Updated link_whatsapp untuk baris 36
# ✔️ Updated template_pesan untuk baris 36
# ✔️ Updated link_whatsapp untuk baris 37
# ✔️ Updated template_pesan untuk baris 37
# ✔️ Updated link_whatsapp untuk baris 39
# ✔️ Updated template_pesan untuk baris 39
# ✔️ Updated link_whatsapp untuk baris 40
# ✔️ Updated template_pesan untuk baris 40
# ✔️ Updated link_whatsapp untuk baris 41
# ✔️ Updated template_pesan untuk baris 41
# ✔️ Updated link_whatsapp untuk baris 42
# ✔️ Updated template_pesan untuk baris 42
# ✔️ Updated link_whatsapp untuk baris 43
# ✔️ Updated template_pesan untuk baris 43
# ✔️ Updated link_whatsapp untuk baris 44
# ✔️ Updated template_pesan untuk baris 44
# ✔️ Updated link_whatsapp untuk baris 45
# ✔️ Updated template_pesan untuk baris 45
# ✔️ Updated link_whatsapp untuk baris 46
# ✔️ Updated template_pesan untuk baris 46
# ✔️ Updated link_whatsapp untuk baris 47
# ✔️ Updated template_pesan untuk baris 47
# ✔️ Updated link_whatsapp untuk baris 48
# ✔️ Updated template_pesan untuk baris 48
# ✔️ Updated link_whatsapp untuk baris 49
# ✔️ Updated template_pesan untuk baris 49
# ✔️ Updated link_whatsapp untuk baris 50
# ✔️ Updated template_pesan untuk baris 50
# ✔️ Updated link_whatsapp untuk baris 51
# ✔️ Updated template_pesan untuk baris 51
# ✔️ Updated link_whatsapp untuk baris 52
# ✔️ Updated template_pesan untuk baris 52
# ✔️ Updated link_whatsapp untuk baris 53
# ✔️ Updated template_pesan untuk baris 53
# ✔️ Updated link_whatsapp untuk baris 54
# ✔️ Updated template_pesan untuk baris 54
# ✔️ Updated link_whatsapp untuk baris 55
# ✔️ Updated template_pesan untuk baris 55
# ✔️ Updated link_whatsapp untuk baris 56
# ✔️ Updated template_pesan untuk baris 56
# ✔️ Updated link_whatsapp untuk baris 57
# ✔️ Updated template_pesan untuk baris 57
# ✔️ Updated link_whatsapp untuk baris 58
# ✔️ Updated template_pesan untuk baris 58
# ✔️ Updated link_whatsapp untuk baris 59
# ✔️ Updated template_pesan untuk baris 59
# ✔️ Updated link_whatsapp untuk baris 60
# ✔️ Updated template_pesan untuk baris 60
# ✔️ Updated link_whatsapp untuk baris 61
# ✔️ Updated template_pesan untuk baris 61
# ✔️ Updated link_whatsapp untuk baris 62
# ✔️ Updated template_pesan untuk baris 62
# ✔️ Updated link_whatsapp untuk baris 63
# ✔️ Updated template_pesan untuk baris 63
# ✔️ Updated link_whatsapp untuk baris 64
# ✔️ Updated template_pesan untuk baris 64
# ✔️ Updated link_whatsapp untuk baris 65
# ✔️ Updated template_pesan untuk baris 65
# ✔️ Updated link_whatsapp untuk baris 66
# ✔️ Updated template_pesan untuk baris 66
# ✔️ Updated link_whatsapp untuk baris 67
# ✔️ Updated template_pesan untuk baris 67
# ✔️ Updated link_whatsapp untuk baris 68
# ✔️ Updated template_pesan untuk baris 68
# ✔️ Updated link_whatsapp untuk baris 69
# ✔️ Updated template_pesan untuk baris 69
# ✔️ Updated link_whatsapp untuk baris 70
# ✔️ Updated template_pesan untuk baris 70
# ✔️ Updated link_whatsapp untuk baris 71
# ✔️ Updated template_pesan untuk baris 71
# ✔️ Updated link_whatsapp untuk baris 72
# ✔️ Updated template_pesan untuk baris 72
# ✔️ Updated link_whatsapp untuk baris 73
# ✔️ Updated template_pesan untuk baris 73
# ✔️ Updated link_whatsapp untuk baris 74
# ✔️ Updated template_pesan untuk baris 74
# ✔️ Updated link_whatsapp untuk baris 75
# ✔️ Updated template_pesan untuk baris 75
# ✔️ Updated link_whatsapp untuk baris 76
# ✔️ Updated template_pesan untuk baris 76
# ✔️ Updated link_whatsapp untuk baris 77
# ✔️ Updated template_pesan untuk baris 77
# ✔️ Updated link_whatsapp untuk baris 78
# ✔️ Updated template_pesan untuk baris 78
# ✔️ Updated link_whatsapp untuk baris 79
# ✔️ Updated template_pesan untuk baris 79
# ✔️ Updated link_whatsapp untuk baris 80
# ✔️ Updated template_pesan untuk baris 80
# ✔️ Updated link_whatsapp untuk baris 81
# ✔️ Updated template_pesan untuk baris 81
# ✔️ Updated link_whatsapp untuk baris 82
# ✔️ Updated template_pesan untuk baris 82
# ✔️ Updated link_whatsapp untuk baris 83
# ✔️ Updated template_pesan untuk baris 83
# ✔️ Updated link_whatsapp untuk baris 84
# ✔️ Updated template_pesan untuk baris 84
# ✔️ Updated link_whatsapp untuk baris 85
# ✔️ Updated template_pesan untuk baris 85
# ✔️ Updated link_whatsapp untuk baris 86
# ✔️ Updated template_pesan untuk baris 86
# ✔️ Updated link_whatsapp untuk baris 87
# ✔️ Updated template_pesan untuk baris 87
# ✔️ Updated link_whatsapp untuk baris 88
# ✔️ Updated template_pesan untuk baris 88
# ✔️ Updated link_whatsapp untuk baris 89
# ✔️ Updated template_pesan untuk baris 89
# ✔️ Updated link_whatsapp untuk baris 90
# ✔️ Updated template_pesan untuk baris 90
#
# ⛔ Error Summary:
# ❌ Error saat memproses AZWA IZADENT KHAFZA’I: Character "’" at index 19 in text is outside the range of characters supported by the font used: "helvetica". Please consider using a Unicode font.
#
# ✅ Proses selesai!
