# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKai7/invoice_generator/blob/main/fun_run_unipma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang diperlukan
# !pip install gspread pandas fpdf2 pyqrcode pypng requests pillow
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2

# Import library yang dibutuhkan
import gspread
from google.colab import auth
from google.auth import default
import pandas as pd
from fpdf import FPDF
import os
from google.colab import drive
from datetime import datetime
import requests
from io import BytesIO
from PIL import Image
import urllib.parse
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Autentikasi Google Colab dengan Google Sheets & Drive
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Inisialisasi Google Drive API
drive_service = build('drive', 'v3', credentials=creds)

# Mount Google Drive untuk menyimpan invoice
drive.mount('/content/drive')

# Buka spreadsheet
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1ex0lbjBt2L1Y4iC_myPhc8SNE4Yj4wdngBC8oz509Dg/edit?gid=0#gid=0"
sh = gc.open_by_url(spreadsheet_url)
worksheet = sh.get_worksheet(0)

# Ambil semua data dan periksa kolom yang tersedia
expected_headers = ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
records = worksheet.get_all_records(expected_headers=expected_headers)
df = pd.DataFrame.from_records(records)


# Periksa nama kolom yang sebenarnya
print("Kolom yang tersedia di spreadsheet:")
print(df.columns.tolist())

# Pastikan nama kolom sesuai dengan spreadsheet Anda
COLUMN_MAPPING = {
    'invoice_id': 'KODE_INVOICE',
    'name': 'NAMA',
    'category': 'KATEGORI',
    'barcode': 'BARCODE',
    'whatsapp': 'NO_WA',
    'address': 'ALAMAT'
}

# Path logo di Google Drive (sesuaikan dengan path Anda)
LOGO_DIES_PATH = '/content/drive/MyDrive/logo/diesnatalis 1-01.png'  # Ganti dengan path yang benar
LOGO_UNIPMA_PATH = '/content/drive/MyDrive/logo/Unipma.png'  # Ganti dengan path yang benar

class InvoicePDF(FPDF):
    def __init__(self, participant_data):
        super().__init__(format='A4', orientation='L')  # A4 Landscape
        self.participant_data = participant_data
        self.add_page()

    def header(self):
        # Tambahkan background dengan efek fade
        self._add_faded_background()

        # Tambahkan logo jika file ada
        try:
            # Logo Dies Natalis di kiri - ukuran disesuaikan
            if os.path.exists(LOGO_UNIPMA_PATH):
                self.image(LOGO_UNIPMA_PATH, x=15, y=15, w=30)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading UNIPMA logo: {e}")

        try:
            # Logo UNIPMA di kanan - ukuran disesuaikan
            if os.path.exists(LOGO_DIES_PATH):
                self.image(LOGO_DIES_PATH, x=210, y=0, w=100)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading Dies Natalis logo: {e}")

        # Judul
        self.set_y(25)
        self.set_font('Arial', 'B', 18)
        self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
        self.set_font('Arial', 'I', 12)
        self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
        self.ln(5)

    def _add_faded_background(self):
        # Path ke gambar background (sesuaikan dengan path Anda)
        BG_IMAGE_PATH = '/content/drive/MyDrive/logo/asset diesnat fun run/bg1.jpg'  # Ganti dengan path gambar background Anda

        if os.path.exists(BG_IMAGE_PATH):
            try:
                # Simpan posisi Y saat ini
                current_y = self.get_y()

                # Geser gambar 20px ke kiri (nilai negatif) dan perluas lebar untuk menutupi area yang kosong
                x_offset = -15  # Sesuaikan nilai ini untuk mengatur seberapa jauh ke kiri
                adjusted_width = self.w + abs(x_offset)  # Tambahkan lebar untuk kompensasi pergeseran

                # Tambahkan gambar background dengan opacity rendah
                self.image(BG_IMAGE_PATH, x=x_offset, y=0, w=adjusted_width, h=self.h)

                # Tambahkan layer semi-transparan untuk efek fade
                self.set_fill_color(255, 255, 255, 200)  # Putih dengan alpha 200/255 (~78% opacity)
                self.rect(0, 0, self.w, self.h, style='F')

                # Kembalikan posisi Y
                self.set_y(current_y)
            except Exception as e:
                print(f"⚠️ Error adding background: {e}")
        else:
            print("⚠️ Background image not found, skipping...")

    def footer(self):
        # Thank you message di bagian footer tengah
        self.set_y(-15)
        self.set_font('Arial', 'I', 12)
        self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')

    def create_invoice(self):
        # Informasi invoice
        self.set_font('Arial', 'B', 14)
        self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')

        # Tanggal
        self.set_font('Arial', '', 11)
        self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
        self.ln(8)

        # Garis pemisah
        self.line(10, self.get_y(), 287, self.get_y())
        self.ln(10)

        # Layout 3 kolom dengan alignment yang presisi
        col_width = 85
        start_y = self.get_y()  # Simpan posisi Y awal

        # Kolom 1: Data peserta
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
        self.set_font('Arial', '', 11)

        # Simpan posisi Y untuk alignment
        y_details = self.get_y()

        # Initialize name_y at the beginning
        name_y = y_details

        # Nama (baseline untuk alignment)
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Nama:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
        self.ln(2)
        name_y = self.get_y()

        # WhatsApp jika ada
        if COLUMN_MAPPING["whatsapp"] in self.participant_data and self.participant_data[COLUMN_MAPPING["whatsapp"]]:
            whatsapp_num = str(self.participant_data[COLUMN_MAPPING["whatsapp"]])
            clean_number = ''.join(filter(str.isdigit, whatsapp_num))
            if clean_number.startswith('0'):
                clean_number = '+62' + clean_number[1:]
            elif not clean_number.startswith('62'):
                clean_number = '+62' + clean_number
            else:
                clean_number = '+' + clean_number

            self.set_font('Arial', 'B', 11)
            self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
            self.set_font('Arial', '', 11)
            self.cell(col_width, 6, clean_number, ln=1, align='L')
            self.ln(2)

        # Alamat jika ada
        if COLUMN_MAPPING["address"] in self.participant_data:
            address = self.participant_data[COLUMN_MAPPING["address"]]
            if pd.notna(address) and str(address).strip() != '':
                self.set_font('Arial', 'B', 11)
                self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
                self.set_font('Arial', '', 11)
                self.multi_cell(col_width, 6, str(address), align='L')
                self.ln(2)

        # Kategori
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
        self.ln(2)

        # Kolom 2: Detail pengambilan race pack (tengah)
        self.set_xy(120, y_details - 5)  # Sejajar dengan "PARTICIPANT DETAILS"
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')

        # Posisikan konten race pack sejajar dengan "Name" di X=100
        self.set_xy(100, name_y - 10)  # X=100, Y sejajar dengan "Name"
        self.set_font('Arial', '', 11)

        # Format lengkap dengan indentasi yang tepat
        race_pack_content = [
          ("Tanggal:", 0),                     # Header - no indent
          ("- 30 Mei 2025", 0),                # Date 1 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-16.00", 10),       # Session 2 - indent 10
          ("- 31 Mei 2025", 0),                # Date 2 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-15.00", 10),       # Session 2 - indent 10
          ("", 0),                             # Empty line
          ("Lokasi:", 0),                      # Location header - no indent
          ("Laboratorium Terpadu UNIPMA", 0)   # Location - no indent
        ]

        # Cetak dengan indentasi yang konsisten
        for line, indent in race_pack_content:
            self.set_x(120 + indent)
            self.cell(col_width - indent, 6, line, ln=1, align='L')

        # Kolom 3: Barcode/QR code
        if COLUMN_MAPPING["barcode"] in self.participant_data and self.participant_data[COLUMN_MAPPING["barcode"]]:
            try:
                response = requests.get(self.participant_data[COLUMN_MAPPING["barcode"]])
                img = Image.open(BytesIO(response.content))

                temp_img_path = f"/tmp/barcode_{self.participant_data[COLUMN_MAPPING['invoice_id']]}.png"
                img.save(temp_img_path)

                # Posisi di kolom kanan, sejajar dengan "Name"
                x_position = 220
                y_position = name_y - 15  # Adjust to align with "Name"

                self.image(temp_img_path, x=x_position, y=y_position, w=60)

                # Teks di bawah barcode
                self.set_xy(x_position, y_position + 56)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')

                # Teks di bawah barcode 2
                self.set_xy(x_position, y_position + 61)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')

                os.remove(temp_img_path)
            except Exception as e:
                print(f"⚠️ Error adding barcode: {e}")

        # Notes di bagian bawah - diposisikan lebih tinggi
        notes_y = max(self.get_y() + 1, 120)  # Mengurangi 15pt dari posisi sebelumnya
        self.set_xy(10, notes_y)
        self.set_font('Arial', 'I', 11)
        notes = [
            "Catatan:",
            "- Harap datang tepat waktu sesuai sesi yang dipilih",
            "- Tunjukkan barcode ini saat pengambilan race pack",
            "- Bawa identitas yang valid (KTP/SIM/KTM/KARTU PELAJAR)"
        ]
        for note in notes:
            self.cell(0, 6, note, ln=1, align='L')

def generate_invoice_pdf(participant_data):
    # Buat PDF
    pdf = InvoicePDF(participant_data)
    pdf.create_invoice()

    # Buat folder penyimpanan di Colab
    local_invoice_dir = "/content/invoices"
    os.makedirs(local_invoice_dir, exist_ok=True)

    # Simpan PDF lokal
    pdf_filename = f"FUN RUN UNIPMA_{participant_data[COLUMN_MAPPING['invoice_id']]}.pdf"
    local_pdf_path = f"{local_invoice_dir}/{pdf_filename}"
    pdf.output(local_pdf_path)

    return local_pdf_path, pdf_filename

def upload_to_drive(file_path, file_name, folder_id=None):
    """Upload file ke Google Drive dan set permissions"""
    file_metadata = {
        'name': file_name,
        'parents': [folder_id] if folder_id else None
    }

    media = MediaFileUpload(file_path, mimetype='application/pdf')

    file = drive_service.files().create(
        body=file_metadata,
        media_body=media,
        fields='id,webViewLink'
    ).execute()

    # Set permissions agar bisa diakses oleh siapa saja dengan link
    permission = {
        'type': 'anyone',
        'role': 'reader'
    }

    drive_service.permissions().create(
        fileId=file['id'],
        body=permission
    ).execute()

    return file['webViewLink']

def generate_whatsapp_link(phone_number):
    if pd.isna(phone_number) or not phone_number:
        return ""

    # Format nomor WhatsApp (62XXXXXXXXXX)
    clean_number = ''.join(filter(str.isdigit, str(phone_number)))
    if clean_number.startswith('0'):
        clean_number = '62' + clean_number[1:]
    elif not clean_number.startswith('62'):
        clean_number = '62' + clean_number
    return f"https://wa.me/{clean_number}"

def generate_message_template(participant_data, drive_link):
    # Format WhatsApp number dengan +62
    whatsapp_num = str(participant_data.get(COLUMN_MAPPING['whatsapp'], ''))
    if whatsapp_num:
        clean_number = ''.join(filter(str.isdigit, whatsapp_num))
        if clean_number.startswith('0'):
            clean_number = '+62' + clean_number[1:]
        elif not clean_number.startswith('62'):
            clean_number = '+62' + clean_number
        else:
            clean_number = '+' + clean_number
    else:
        clean_number = ''

    return f"""
Halo {participant_data[COLUMN_MAPPING['name']]},

Terima kasih telah mendaftar di *UNIPMA FUN RUN 5K 2025*!
Berikut invoice resmi Anda:

🔹 *Kode Invoice:* {participant_data[COLUMN_MAPPING['invoice_id']]}
🔹 *Kategori:* {participant_data[COLUMN_MAPPING['category']]}
🔹 *Alamat:* {participant_data[COLUMN_MAPPING['address']]}


📥 *Download Invoice:*
{drive_link}

*Info Pengambilan Race Pack:*
📅 *Tanggal:*
- 30 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-16.00)
- 31 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-15.00)
🏫 *Lokasi:* Laboratorium Terpadu UNIPMA

*Catatan:*
- Harap datang tepat waktu sesuai sesi yang dipilih
- Tunjukkan barcode yang ada pada invoice saat pengambilan racepack
- Bawa identitas yang valid(KTP/SIM/KTM/KARTU PELAJAR)

Mohon simpan invoice ini sebagai bukti pendaftaran.
Jika ada pertanyaan, hubungi kami via WhatsApp.

Salam,
*Panitia Unipma Fun Run 5K 2025*
"""

def process_all_participants():
    updates = []
    errors = []

    # ID folder tujuan di Google Drive (ganti dengan folder ID Anda)
    DRIVE_FOLDER_ID = '1A8ADXVlMOHPJsBhvaxZuBjL7egO3Wq2_'  # Ganti dengan folder ID tujuan

    for index, row in df.iterrows():
        try:
            invoice_id = row[COLUMN_MAPPING['invoice_id']]
            print(f"\nMemproses peserta: {row.get(COLUMN_MAPPING['name'], '')} (Invoice: {invoice_id})")

            # 1. Generate PDF
            local_pdf_path, pdf_filename = generate_invoice_pdf(row)

            # 2. Upload ke Google Drive dan dapatkan link
            drive_link = upload_to_drive(local_pdf_path, pdf_filename, DRIVE_FOLDER_ID)
            print(f"✅ Invoice diupload ke: {drive_link}")

            # 3. Generate link WhatsApp
            whatsapp_link = generate_whatsapp_link(row.get(COLUMN_MAPPING['whatsapp'], ''))
            updates.append((index, 'link_whatsapp', whatsapp_link))

            # 4. Buat template pesan
            message = generate_message_template(row, drive_link)
            updates.append((index, 'template_pesan', message))

            # 5. Bersihkan file lokal
            os.remove(local_pdf_path)

        except Exception as e:
            error_msg = f"❌ Error saat memproses {row.get(COLUMN_MAPPING['name'], '')}: {str(e)}"
            print(error_msg)
            errors.append((index, error_msg))

    # Update spreadsheet
    for update in updates:
        row_idx, col_name, value = update
        try:
            # Cari kolom yang sesuai
            col_names = [col.lower() for col in df.columns]
            target_col = col_name.lower()

            if target_col in col_names:
                col_idx = col_names.index(target_col) + 1  # +1 karena indeks spreadsheet mulai dari 1
                worksheet.update_cell(row_idx + 2, col_idx, value)
                print(f"✔️ Updated {col_name} untuk baris {row_idx + 2}")
            else:
                print(f"⚠️ Kolom {col_name} tidak ditemukan di spreadsheet")
        except Exception as e:
            print(f"❌ Gagal mengupdate spreadsheet untuk baris {row_idx}: {str(e)}")

    # Tampilkan error summary
    if errors:
        print("\n⛔ Error Summary:")
        for error in errors:
            print(error[1])

# Jalankan proses utama
process_all_participants()
print("\n✅ Proses selesai!")
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.11/dist-packages (6.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: fpdf2 in /usr/local/lib/python3.11/dist-packages (2.8.3)
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: pypng in /usr/local/lib/python3.11/dist-packages (0.20220715.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from gspread) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gspread) (1.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (4.58.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.38.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.4.26)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Kolom yang tersedia di spreadsheet:
# ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
#
# Memproses peserta: Rohmat bagus tri bagio (Invoice: ROH-1-4466)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# <ipython-input-10-47b2cee7081e>:88: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 18)
# <ipython-input-10-47b2cee7081e>:89: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
# <ipython-input-10-47b2cee7081e>:90: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-10-47b2cee7081e>:91: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
# <ipython-input-10-47b2cee7081e>:129: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 14)
# <ipython-input-10-47b2cee7081e>:130: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')
# <ipython-input-10-47b2cee7081e>:133: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:134: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
# <ipython-input-10-47b2cee7081e>:146: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-10-47b2cee7081e>:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
# <ipython-input-10-47b2cee7081e>:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:157: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-10-47b2cee7081e>:158: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Nama:', ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:159: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:160: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:175: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-10-47b2cee7081e>:176: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:177: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:178: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, clean_number, ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:185: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-10-47b2cee7081e>:186: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:187: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:192: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-10-47b2cee7081e>:193: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:194: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:195: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:200: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-10-47b2cee7081e>:201: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')
# <ipython-input-10-47b2cee7081e>:205: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-10-47b2cee7081e>:224: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width - indent, 6, line, ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:243: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-10-47b2cee7081e>:244: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')
# <ipython-input-10-47b2cee7081e>:248: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-10-47b2cee7081e>:249: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')
# <ipython-input-10-47b2cee7081e>:258: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 11)
# <ipython-input-10-47b2cee7081e>:266: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 6, note, ln=1, align='L')
# <ipython-input-10-47b2cee7081e>:124: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-10-47b2cee7081e>:125: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=0 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')
# ✅ Invoice diupload ke: https://drive.google.com/file/d/158igtSdMY7v2eFBiqZsjYpxNjdZ6UEHZ/view?usp=drivesdk
#
# Memproses peserta: Septyan Ali Islamudin (Invoice: SEP-1-4471)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1x93Kd1LjJ3AqUgh3KhEbi982ayZGWlkX/view?usp=drivesdk
#
# Memproses peserta: Jona Bagus Prakoso (Invoice: JON-1-5869)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1u0VRR8fIMangP_ypymzF039tWqkj-2Bl/view?usp=drivesdk
#
# Memproses peserta: RIFAT SUNGKAR  (Invoice: RIF-1-8476)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ducOxl8WSyRTI3-zksURQzKyPZPlMasn/view?usp=drivesdk
#
# Memproses peserta: Mu’ammar Ahmad (Invoice: MU’-1-1824)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ❌ Error saat memproses Mu’ammar Ahmad: Character "’" at index 11 in text is outside the range of characters supported by the font used: "helveticaB". Please consider using a Unicode font.
#
# Memproses peserta: nafissa dewi alfauziah (Invoice: NAF-1-7006)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1UvfNyeMVeHq21UDuU6ITiauWEuG0bWRu/view?usp=drivesdk
#
# Memproses peserta: FAHRY CAHYO NUGROHO (Invoice: FAH-1-2796)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cMUYq3-oa-H_4CQPPmcrlFQnzTt3xk_A/view?usp=drivesdk
#
# Memproses peserta: Maheswara Widagdo (Invoice: MAH-1-7464)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/104BTqjj2kxgrH9zkn3nAaVgzVpENuMr4/view?usp=drivesdk
#
# Memproses peserta: RENO NUR CHOLIS (Invoice: REN-1-5212)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1dq1ac-WUOdbt0HR47SNPzcrZNelEPeKc/view?usp=drivesdk
#
# Memproses peserta: RIVANDRA YOGA FEYBRIANTO (Invoice: RIV-1-6151)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1t9_2xxqZY3GqEzmKMDIw9FtpywQvsD7F/view?usp=drivesdk
#
# Memproses peserta: zaveta flora alika r (Invoice: ZAV-1-4217)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1EsZ27wjDmoKs55w29jA-Mexc6-nhuvax/view?usp=drivesdk
#
# Memproses peserta: LISA ANDRIANI  (Invoice: LIS-1-8506)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ueYK3SGetQV5VmwLKf0vAuiDnTMnlEe8/view?usp=drivesdk
#
# Memproses peserta: Rendi Kusuma Bakti (Invoice: REN-1-3809)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RFkTHN7T_oHEbfUMuIO1c7jtggKgHKmR/view?usp=drivesdk
#
# Memproses peserta: Danendra farraz hazim  (Invoice: DAN-1-2899)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1R5ao_WovdYDthvJkKUtBTcXiJCwjt3ys/view?usp=drivesdk
#
# Memproses peserta: Orion Kusuma Amadeo  (Invoice: ORI-1-2939)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1LrtkquFD9XiR67yKvMDBLXgdSOatgxYX/view?usp=drivesdk
#
# Memproses peserta: Nathan Edwarddian (Invoice: NAT-1-0790)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Q-YTuCeN6lCFkVAkrdS6owmkElZVuCri/view?usp=drivesdk
#
# Memproses peserta: Azzahra Oviten Firstasari (Invoice: AZZ-1-3427)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1rsn_B9SzVViW5OLavkgDnjglQavV8b4a/view?usp=drivesdk
#
# Memproses peserta: Muhammad Daffa Faisa Manaf Adhipratama  (Invoice: MUH-1-0388)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1P9J1z_K98pDa7y_D28dHdtg2VolhVVgx/view?usp=drivesdk
#
# Memproses peserta: Aisha birkha achsani (Invoice: AIS-1-6606)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1b68bJm6vjTds1c9AenjZ64XM5i-_bSFz/view?usp=drivesdk
#
# Memproses peserta: R.JOVANO S.E.P (Invoice: R.J-1-8050)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zSGYp5bfY5SOXPC8OD_UuAq4caqTt_x1/view?usp=drivesdk
#
# Memproses peserta: BAGAS PUTRA PRATAMA (Invoice: BAG-1-0605)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jXlfroRm_-sU6uadwcSK5SF2VT6cNiFx/view?usp=drivesdk
#
# Memproses peserta: Andi wahyu jatmiko (Invoice: AND-1-6360)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1T0khrn6o-DNfi_5E4m3B6xr-uhoNmLar/view?usp=drivesdk
#
# Memproses peserta: Galih Naufal Airlangga (Invoice: GAL-1-9257)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1UUhaDZFLTZpJeiNiq8CvFtKBz9R_N27d/view?usp=drivesdk
#
# Memproses peserta: Raditya hega erdiyansya'ah  (Invoice: RAD-1-4343)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xYTI8fH0hWDD5MYyaGOY2u8M20lDUfQD/view?usp=drivesdk
#
# Memproses peserta: Hans oktaviandra  (Invoice: HAN-1-6335)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1LaCcHph979UCAK9aPyDZH7h14rvvWzwy/view?usp=drivesdk
#
# Memproses peserta: Habiburrahman Mustofa  (Invoice: HAB-1-0950)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1BX7JmYWZ6TLQDMJVVped_xRg5aWKklGA/view?usp=drivesdk
#
# Memproses peserta: Gibran wahyu nurcahyo (Invoice: GIB-1-3750)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1GZRJ8DNGAHgsr9cO1FoE-yU2wHv1t0wP/view?usp=drivesdk
#
# Memproses peserta: Afif Nasiatul Abidah (Invoice: AFI-1-1825)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1AeJ8qcQtrQrXsh8JJaguI-p1zk14KI6O/view?usp=drivesdk
#
# Memproses peserta: Muhammad Razzan Rianda Putra (Invoice: MUH-1-2125)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/16OhFL91cHcanlMQ2_RkSKzcevOe13m0_/view?usp=drivesdk
#
# Memproses peserta: fahrie irham maulana lihu (Invoice: FAH-1-2201)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/15unK8nVdJ5nPTGx5Tul0b-V_cqJfhbab/view?usp=drivesdk
#
# Memproses peserta: Mochammad Galang Ramadhan (Invoice: MOC-1-9356)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_jHRmuIcF2uc1hvEvlbQFCQ-1QPHXFpI/view?usp=drivesdk
#
# Memproses peserta: LUKY ARIZAL MUBAROK (Invoice: LUK-1-3037)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zy4Qfyd95-z_6_TMz7YQ6fle_xpVh3Un/view?usp=drivesdk
#
# Memproses peserta: ALIF AGUS FATKURROHMAN (Invoice: ALI-1-3682)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1sR0zr6tufmLbL-kFLjzL33UWEE151mex/view?usp=drivesdk
#
# Memproses peserta: DAVID SURYA SAPUTRA  (Invoice: DAV-1-4964)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1T-k2gAHniZdVkdQSP7zdrPg22aEkTsmQ/view?usp=drivesdk
#
# Memproses peserta: Mifta Devi Qulhudiawati  (Invoice: MIF-1-3677)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1BO28UaYWGzMQTxQcDb-axIlsrz-ehOCJ/view?usp=drivesdk
#
# Memproses peserta: Anggita Ayu Pratiwi (Invoice: ANG-1-7924)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1admQ7jqSfTp3WWoZIpJWRjULOhUOlPUx/view?usp=drivesdk
#
# Memproses peserta: Jennie Marcella Damayanti (Invoice: JEN-1-4486)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1sFIQKM4OAAZ45vHfp0F66yml56qOnCNE/view?usp=drivesdk
#
# Memproses peserta: Salsabilla Zahrin Latifa  (Invoice: SAL-1-8128)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1-3aQLjsJ2kJBoFdXQtyL4Rvjkr4G-UM2/view?usp=drivesdk
#
# Memproses peserta: Anton Prastyo (Invoice: ANT-1-6976)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1qvOUHFTpktqR-6WCVXm13SsNPvIKl0W7/view?usp=drivesdk
#
# Memproses peserta: Kenzie Ardiansyah Marhaendra (Invoice: KEN-1-9798)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1f-BUqMOLxRK2EbQWXZxvt15vLLkk9CZ8/view?usp=drivesdk
#
# Memproses peserta: R. RUDY YUDHA PRATAMA (Invoice: R. -1-0584)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1wGrHNN_chp1KflRMNTVFl1Ic8Y3h8WgK/view?usp=drivesdk
#
# Memproses peserta: RIZKUNA DWI PANGESTU (Invoice: RIZ-1-5297)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/16qyfbWNUb-5Tf1vIxplVwvHDfMqAo0rs/view?usp=drivesdk
#
# Memproses peserta: Aris Gangsar Widiyanto (Invoice: ARI-1-4382)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zTigL34Kh1gVNdSOksOmHtdhLpDWtjZh/view?usp=drivesdk
#
# Memproses peserta: MUHAMMAD RAFSYA NIHAD (Invoice: MUH-1-3465)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1DyIZke-AloNA_GFi6kn7LTz29IEKVbla/view?usp=drivesdk
#
# Memproses peserta: LA ODE ARDI FERDIANTO (Invoice: LA -1-1607)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1z1S3saAtETfLgCffXuutZp4el1Qt0oot/view?usp=drivesdk
#
# Memproses peserta: Dea Ananda Suhendika  (Invoice: DEA-1-2164)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zOJqOGV7x8ZXzcQfblkViEsfnbWTj6W8/view?usp=drivesdk
#
# Memproses peserta: Ika Puji Rantini (Invoice: IKA-1-6146)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1qtEmez9e8EJeR-xujPZJtXnCsAJXX9xP/view?usp=drivesdk
#
# Memproses peserta: Denis tri hapsari (Invoice: DEN-1-5310)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Q4tmw6t-0rXFUofzAnpXPnluRd5_IEuO/view?usp=drivesdk
#
# Memproses peserta: Graveo Wicaksana (Invoice: GRA-1-5525)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19m93mHOrA3P4H-ZS8vp4dkOyJv1a1ojg/view?usp=drivesdk
#
# Memproses peserta: Kristiani (Invoice: KRI-1-5525)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/17gyTsZ_ZEqKBsH6LACyMnY3q_7md19Uz/view?usp=drivesdk
#
# Memproses peserta: Valentino vernandho Haryono (Invoice: VAL-1-9964)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1NCyQHTAxtd_LRL1-R9X05QQiYQmgqioB/view?usp=drivesdk
#
# Memproses peserta: Daffa Adinata Gunawan (Invoice: DAF-1-5755)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1bM-bJd7MgOcrGMwHfctkOLtNj2I__erA/view?usp=drivesdk
#
# Memproses peserta: ALMAHYRA BANAFSHA RAMADHANI (Invoice: ALM-1-4069)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/15xjbBC0cp1yWxnUZbSVNGAHbrC0ln8QH/view?usp=drivesdk
#
# Memproses peserta: SHERINA AYU SETYANINGRUM (Invoice: SHE-1-7229)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1owIKJRedKkdZMoM2CKkRBt0V6cUvbF4i/view?usp=drivesdk
#
# Memproses peserta: Nayyara Aleshadefari (Invoice: NAY-1-3348)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1kYeUSX4ro6MdCR6eSS0qk9vdPUMKY3Gw/view?usp=drivesdk
#
# Memproses peserta: Paksi aqsha jatiwiyono (Invoice: PAK-1-2637)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/174d3tZGGh0nQMA5oAxi07m-w0zno-j1P/view?usp=drivesdk
#
# Memproses peserta: Alliesya zamrotuz zuhro (Invoice: ALL-1-1609)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1DzJrEHmDiRdJSydqVEoa_zUnaJGjXYPC/view?usp=drivesdk
#
# Memproses peserta: AISHA RAHMA NASYRA (Invoice: AIS-1-4046)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1uljdTocdji4pDn_2GH0wyoCgSJLsXAxY/view?usp=drivesdk
#
# Memproses peserta: AZRYL AZZA ASEGAF (Invoice: AZR-1-1060)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ld2asj0h6obp5kebOdhfL4mml_gllMGP/view?usp=drivesdk
#
# Memproses peserta: PRIDA IVIAN VIRGINATA PUTRI (Invoice: PRI-1-3689)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1hUHnQDdm0DyHNe_ZVW3uaxaDVvIoV_NP/view?usp=drivesdk
#
# Memproses peserta: AQELA YASIR (Invoice: AQE-1-0048)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1yBGSiq2CG0aNMENqv29_A-iYHmUWb88F/view?usp=drivesdk
#
# Memproses peserta: ALFIYAH RIZKY HARTANTO (Invoice: ALF-1-2990)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1yJSdvvVMoeCCnj9hUgLnognmrXaaqs13/view?usp=drivesdk
#
# Memproses peserta: ANANDIA CHIKA FEBRIOLA (Invoice: ANA-1-6280)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cA2Gv3sRn2pro_lmynBJEHjkht6x63-b/view?usp=drivesdk
#
# Memproses peserta: Aditya Rifqi Haminzan (Invoice: ADI-1-3314)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1b0kz-mEIrcXbD5NnKuX6sj8w85GTizfQ/view?usp=drivesdk
#
# Memproses peserta: DAYANA FATIN ZAKIAH  (Invoice: DAY-1-0680)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OO0zoOOHnL6HC663Yy2xfpRn6cLfjnsr/view?usp=drivesdk
#
# Memproses peserta: Vincent julio alfa Wibowo  (Invoice: VIN-1-5230)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/14t5q0tcMaoZpF7eaLOvFt7G21wdC8qIL/view?usp=drivesdk
#
# Memproses peserta: YELSE APRILIA INORAWATI  (Invoice: YEL-1-2659)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1zH2WjM1p6knhERls90pKCeUgXNaSq_CA/view?usp=drivesdk
#
# Memproses peserta: Asyifa Dwi Nur Fadhilah (Invoice: ASY-1-4073)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1FwZH1joXPmsxacjhtiniCxQUbdLz8x4l/view?usp=drivesdk
#
# Memproses peserta: GERALDHINO A.S (Invoice: GER-1-8826)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1egrX-6FQN32biIfeRruBAYVpnxDZJtlS/view?usp=drivesdk
#
# Memproses peserta: Saen Ameera Pinatar (Invoice: SAE-1-8486)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1h0sMfs6AN7KC9nRxz_KiPTrMxvIU3fvi/view?usp=drivesdk
#
# Memproses peserta: Yogiswara Arimurti (Invoice: YOG-1-0245)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1iAChGUXdqvaK9fsu1ZRB65cEN-SDKqr1/view?usp=drivesdk
#
# Memproses peserta: rangga surya aldiansyah (Invoice: RAN-1-6496)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1s7AXXW5hitBftby1VAGtq7fikjoueAsq/view?usp=drivesdk
#
# Memproses peserta: SYAQILA ANASTASYA WAHYUDI (Invoice: SYA-1-9296)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MZuDcITj-qIh0tG6kNs2ke7Cr7pZtP7Y/view?usp=drivesdk
#
# Memproses peserta: Arga pratama putra (Invoice: ARG-1-6644)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/15zZzd5LA7Puas6cByS9bQNT6CTpbDZdF/view?usp=drivesdk
#
# Memproses peserta: NAJWATUL AQILAH (Invoice: NAJ-1-0040)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10N02_P1ik85pYpZNybc4hqDX9wINoIKd/view?usp=drivesdk
#
# Memproses peserta: DARMA PUTRA SEJATI  (Invoice: DAR-1-6579)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1nIRM09QENjIL2XAybMWgT5hjQz8NaiWq/view?usp=drivesdk
#
# Memproses peserta: Mifta Aji Zakaria  (Invoice: MIF-1-2756)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/157lTf7kzQP9Tvu2G1euNmlCdHiC7Xog8/view?usp=drivesdk
#
# Memproses peserta: FARAH ALLISYA PUTRI (Invoice: FAR-1-3015)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1JmJug29WY5cQXWkc9LyET9i9MuIccOKg/view?usp=drivesdk
#
# Memproses peserta: Kusnadi (Invoice: KUS-1-1000)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ZtzHoi3mV8gjw-PJv-V8KA3XYV_b7iSH/view?usp=drivesdk
#
# Memproses peserta: ALFALAH BINTANG YUDHISTIRA  (Invoice: ALF-1-4370)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MO0SGPMfW2vAmpuY4YcXhIr36Cj3Jyxs/view?usp=drivesdk
#
# Memproses peserta: Muhammad Yusup Iskandar  (Invoice: MUH-1-2341)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WoFUINk0dJDdm3EvOEw5B3xt5y5SUoUJ/view?usp=drivesdk
#
# Memproses peserta: Rita Susanti (Invoice: RIT-1-0151)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mf5Lw-Wm1eusmNvu2pCGWb5J6ZTz3VMb/view?usp=drivesdk
#
# Memproses peserta: Bambang Sihwiyana  (Invoice: BAM-1-4321)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TU_-EbsqUezjiQqBaRd6TcBCVQj34Mww/view?usp=drivesdk
#
# Memproses peserta: BIMA (Invoice: BIM-1-7687)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1dweUrQO0s6dnjf8ENwAzFtQNQ_ZXnnlH/view?usp=drivesdk
#
# Memproses peserta: Nizaar Deswangga Putra  (Invoice: NIZ-1-0868)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1uT48kHDmIX7kyBGvdixd26pZ2jF-8iuP/view?usp=drivesdk
#
# Memproses peserta: Primaningtyas (Invoice: PRI-1-1733)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1-0preShmcslQTHz9BPABlZ5_FTX6rS89/view?usp=drivesdk
#
# Memproses peserta: Hafidz Dwi Sakti Ramadhan (Invoice: HAF-1-7687)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mdUXNDB1IpTY68o_3Z3lQd0uhOTbBE6d/view?usp=drivesdk
#
# Memproses peserta: RINDY EKA PRATIWI (Invoice: RIN-1-2415)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1f1OjEB-_X9spG3fNffDqwRlAqXfldLTg/view?usp=drivesdk
#
# Memproses peserta: Muhammad Maulana Samudera jati  (Invoice: MUH-1-0399)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WLYk8XZtdI_eLRolpdzUPZRE5kgCaS76/view?usp=drivesdk
#
# Memproses peserta: Muhammad Risky Maulana (Invoice: MUH-1-9257)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1bL7HLPmWHa_KbvXW5qDH8mAQqlIl0YSs/view?usp=drivesdk
#
# Memproses peserta: Nabela Aulya Rosalinda Asri (Invoice: NAB-1-5609)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1pi4GOtnVZGgAZDyVFeBFvKc7EtxG__Ex/view?usp=drivesdk
#
# Memproses peserta: Desi Dwi Ariyanti (Invoice: DES-1-1446)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OE09GBpHCnkmaWF7z6gOUhQ6fjqqGz5H/view?usp=drivesdk
#
# Memproses peserta: Widya Sagita Oktavia Putri (Invoice: WID-1-6233)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1eRBhiZfqFatN51Izpd-VNVzMfgNUUVWS/view?usp=drivesdk
#
# Memproses peserta: Bayu seto aji (Invoice: BAY-1-8475)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Latf7nxCezDjciAm9Ltx2hM1nEiQwh-6/view?usp=drivesdk
#
# Memproses peserta: Abdee Pratama Mahardika  (Invoice: ABD-1-7923)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mJKvOIYwXAqWa_Jm3ppc5DxS9onzh4uB/view?usp=drivesdk
#
# Memproses peserta: Mega Yuwarisna Widianingrum (Invoice: MEG-1-7192)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Y6LyvVlhLqjYwJwwwrHUFLnlTiH4g_4x/view?usp=drivesdk
#
# Memproses peserta: Kevin Volker Veasna Adany  (Invoice: KEV-1-2411)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WSv-MEO8ocN0h_FmrencZ01YrzjbaZ0Q/view?usp=drivesdk
#
# Memproses peserta: NAUFAL YULIAN ALIF RIYANTO (Invoice: NAU-1-8715)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1O4qR9DzNYd5jtzF63ufWVWFJLX4DSjae/view?usp=drivesdk
#
# Memproses peserta: Khorin Atus Sholikah (Invoice: KHO-1-4621)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1W7DhGR7DY42qsZjCra_43jaH0ao8griZ/view?usp=drivesdk
#
# Memproses peserta: ANASTASYA GANDINI HERLIANA PUTRI  (Invoice: ANA-1-5738)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Sbl0BRX9NZFfzl6T8eyPvfuYVFd0dJh9/view?usp=drivesdk
#
# Memproses peserta: Muhammad faishol falaah  (Invoice: MUH-1-4997)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10Qa3Jsgk1x8e8z0Mut9K_L1bTqydNgWa/view?usp=drivesdk
# ✔️ Updated link_whatsapp untuk baris 2
# ✔️ Updated template_pesan untuk baris 2
# ✔️ Updated link_whatsapp untuk baris 3
# ✔️ Updated template_pesan untuk baris 3
# ✔️ Updated link_whatsapp untuk baris 4
# ✔️ Updated template_pesan untuk baris 4
# ✔️ Updated link_whatsapp untuk baris 5
# ✔️ Updated template_pesan untuk baris 5
# ✔️ Updated link_whatsapp untuk baris 7
# ✔️ Updated template_pesan untuk baris 7
# ✔️ Updated link_whatsapp untuk baris 8
# ✔️ Updated template_pesan untuk baris 8
# ✔️ Updated link_whatsapp untuk baris 9
# ✔️ Updated template_pesan untuk baris 9
# ✔️ Updated link_whatsapp untuk baris 10
# ✔️ Updated template_pesan untuk baris 10
# ✔️ Updated link_whatsapp untuk baris 11
# ✔️ Updated template_pesan untuk baris 11
# ✔️ Updated link_whatsapp untuk baris 12
# ✔️ Updated template_pesan untuk baris 12
# ✔️ Updated link_whatsapp untuk baris 13
# ✔️ Updated template_pesan untuk baris 13
# ✔️ Updated link_whatsapp untuk baris 14
# ✔️ Updated template_pesan untuk baris 14
# ✔️ Updated link_whatsapp untuk baris 15
# ✔️ Updated template_pesan untuk baris 15
# ✔️ Updated link_whatsapp untuk baris 16
# ✔️ Updated template_pesan untuk baris 16
# ✔️ Updated link_whatsapp untuk baris 17
# ✔️ Updated template_pesan untuk baris 17
# ✔️ Updated link_whatsapp untuk baris 18
# ✔️ Updated template_pesan untuk baris 18
# ✔️ Updated link_whatsapp untuk baris 19
# ✔️ Updated template_pesan untuk baris 19
# ✔️ Updated link_whatsapp untuk baris 20
# ✔️ Updated template_pesan untuk baris 20
# ✔️ Updated link_whatsapp untuk baris 21
# ✔️ Updated template_pesan untuk baris 21
# ✔️ Updated link_whatsapp untuk baris 22
# ✔️ Updated template_pesan untuk baris 22
# ✔️ Updated link_whatsapp untuk baris 23
# ✔️ Updated template_pesan untuk baris 23
# ✔️ Updated link_whatsapp untuk baris 24
# ✔️ Updated template_pesan untuk baris 24
# ✔️ Updated link_whatsapp untuk baris 25
# ✔️ Updated template_pesan untuk baris 25
# ✔️ Updated link_whatsapp untuk baris 26
# ✔️ Updated template_pesan untuk baris 26
# ✔️ Updated link_whatsapp untuk baris 27
# ✔️ Updated template_pesan untuk baris 27
# ✔️ Updated link_whatsapp untuk baris 28
# ✔️ Updated template_pesan untuk baris 28
# ✔️ Updated link_whatsapp untuk baris 29
# ✔️ Updated template_pesan untuk baris 29
# ✔️ Updated link_whatsapp untuk baris 30
# ✔️ Updated template_pesan untuk baris 30
# ✔️ Updated link_whatsapp untuk baris 31
# ✔️ Updated template_pesan untuk baris 31
# ✔️ Updated link_whatsapp untuk baris 32
# ✔️ Updated template_pesan untuk baris 32
# ✔️ Updated link_whatsapp untuk baris 33
# ✔️ Updated template_pesan untuk baris 33
# ✔️ Updated link_whatsapp untuk baris 34
# ✔️ Updated template_pesan untuk baris 34
# ✔️ Updated link_whatsapp untuk baris 35
# ✔️ Updated template_pesan untuk baris 35
# ✔️ Updated link_whatsapp untuk baris 36
# ✔️ Updated template_pesan untuk baris 36
# ✔️ Updated link_whatsapp untuk baris 37
# ✔️ Updated template_pesan untuk baris 37
# ✔️ Updated link_whatsapp untuk baris 38
# ✔️ Updated template_pesan untuk baris 38
# ✔️ Updated link_whatsapp untuk baris 39
# ✔️ Updated template_pesan untuk baris 39
# ✔️ Updated link_whatsapp untuk baris 40
# ✔️ Updated template_pesan untuk baris 40
# ✔️ Updated link_whatsapp untuk baris 41
# ✔️ Updated template_pesan untuk baris 41
# ✔️ Updated link_whatsapp untuk baris 42
# ✔️ Updated template_pesan untuk baris 42
# ✔️ Updated link_whatsapp untuk baris 43
# ✔️ Updated template_pesan untuk baris 43
# ✔️ Updated link_whatsapp untuk baris 44
# ✔️ Updated template_pesan untuk baris 44
# ✔️ Updated link_whatsapp untuk baris 45
# ✔️ Updated template_pesan untuk baris 45
# ✔️ Updated link_whatsapp untuk baris 46
# ✔️ Updated template_pesan untuk baris 46
# ✔️ Updated link_whatsapp untuk baris 47
# ✔️ Updated template_pesan untuk baris 47
# ✔️ Updated link_whatsapp untuk baris 48
# ✔️ Updated template_pesan untuk baris 48
# ✔️ Updated link_whatsapp untuk baris 49
# ✔️ Updated template_pesan untuk baris 49
# ✔️ Updated link_whatsapp untuk baris 50
# ✔️ Updated template_pesan untuk baris 50
# ✔️ Updated link_whatsapp untuk baris 51
# ✔️ Updated template_pesan untuk baris 51
# ✔️ Updated link_whatsapp untuk baris 52
# ✔️ Updated template_pesan untuk baris 52
# ✔️ Updated link_whatsapp untuk baris 53
# ✔️ Updated template_pesan untuk baris 53
# ✔️ Updated link_whatsapp untuk baris 54
# ✔️ Updated template_pesan untuk baris 54
# ✔️ Updated link_whatsapp untuk baris 55
# ✔️ Updated template_pesan untuk baris 55
# ✔️ Updated link_whatsapp untuk baris 56
# ✔️ Updated template_pesan untuk baris 56
# ✔️ Updated link_whatsapp untuk baris 57
# ✔️ Updated template_pesan untuk baris 57
# ✔️ Updated link_whatsapp untuk baris 58
# ✔️ Updated template_pesan untuk baris 58
# ✔️ Updated link_whatsapp untuk baris 59
# ✔️ Updated template_pesan untuk baris 59
# ✔️ Updated link_whatsapp untuk baris 60
# ✔️ Updated template_pesan untuk baris 60
# ✔️ Updated link_whatsapp untuk baris 61
# ✔️ Updated template_pesan untuk baris 61
# ✔️ Updated link_whatsapp untuk baris 62
# ✔️ Updated template_pesan untuk baris 62
# ✔️ Updated link_whatsapp untuk baris 63
# ✔️ Updated template_pesan untuk baris 63
# ✔️ Updated link_whatsapp untuk baris 64
# ✔️ Updated template_pesan untuk baris 64
# ✔️ Updated link_whatsapp untuk baris 65
# ✔️ Updated template_pesan untuk baris 65
# ✔️ Updated link_whatsapp untuk baris 66
# ✔️ Updated template_pesan untuk baris 66
# ✔️ Updated link_whatsapp untuk baris 67
# ✔️ Updated template_pesan untuk baris 67
# ✔️ Updated link_whatsapp untuk baris 68
# ✔️ Updated template_pesan untuk baris 68
# ✔️ Updated link_whatsapp untuk baris 69
# ✔️ Updated template_pesan untuk baris 69
# ✔️ Updated link_whatsapp untuk baris 70
# ✔️ Updated template_pesan untuk baris 70
# ✔️ Updated link_whatsapp untuk baris 71
# ✔️ Updated template_pesan untuk baris 71
# ✔️ Updated link_whatsapp untuk baris 72
# ✔️ Updated template_pesan untuk baris 72
# ✔️ Updated link_whatsapp untuk baris 73
# ✔️ Updated template_pesan untuk baris 73
# ✔️ Updated link_whatsapp untuk baris 74
# ✔️ Updated template_pesan untuk baris 74
# ✔️ Updated link_whatsapp untuk baris 75
# ✔️ Updated template_pesan untuk baris 75
# ✔️ Updated link_whatsapp untuk baris 76
# ✔️ Updated template_pesan untuk baris 76
# ✔️ Updated link_whatsapp untuk baris 77
# ✔️ Updated template_pesan untuk baris 77
# ✔️ Updated link_whatsapp untuk baris 78
# ✔️ Updated template_pesan untuk baris 78
# ✔️ Updated link_whatsapp untuk baris 79
# ✔️ Updated template_pesan untuk baris 79
# ✔️ Updated link_whatsapp untuk baris 80
# ✔️ Updated template_pesan untuk baris 80
# ✔️ Updated link_whatsapp untuk baris 81
# ✔️ Updated template_pesan untuk baris 81
# ✔️ Updated link_whatsapp untuk baris 82
# ✔️ Updated template_pesan untuk baris 82
# ✔️ Updated link_whatsapp untuk baris 83
# ✔️ Updated template_pesan untuk baris 83
# ✔️ Updated link_whatsapp untuk baris 84
# ✔️ Updated template_pesan untuk baris 84
# ✔️ Updated link_whatsapp untuk baris 85
# ✔️ Updated template_pesan untuk baris 85
# ✔️ Updated link_whatsapp untuk baris 86
# ✔️ Updated template_pesan untuk baris 86
# ✔️ Updated link_whatsapp untuk baris 87
# ✔️ Updated template_pesan untuk baris 87
# ✔️ Updated link_whatsapp untuk baris 88
# ✔️ Updated template_pesan untuk baris 88
# ✔️ Updated link_whatsapp untuk baris 89
# ✔️ Updated template_pesan untuk baris 89
# ✔️ Updated link_whatsapp untuk baris 90
# ✔️ Updated template_pesan untuk baris 90
# ✔️ Updated link_whatsapp untuk baris 91
# ✔️ Updated template_pesan untuk baris 91
# ✔️ Updated link_whatsapp untuk baris 92
# ✔️ Updated template_pesan untuk baris 92
# ✔️ Updated link_whatsapp untuk baris 93
# ✔️ Updated template_pesan untuk baris 93
# ✔️ Updated link_whatsapp untuk baris 94
# ✔️ Updated template_pesan untuk baris 94
# ✔️ Updated link_whatsapp untuk baris 95
# ✔️ Updated template_pesan untuk baris 95
# ✔️ Updated link_whatsapp untuk baris 96
# ✔️ Updated template_pesan untuk baris 96
# ✔️ Updated link_whatsapp untuk baris 97
# ✔️ Updated template_pesan untuk baris 97
# ✔️ Updated link_whatsapp untuk baris 98
# ✔️ Updated template_pesan untuk baris 98
# ✔️ Updated link_whatsapp untuk baris 99
# ✔️ Updated template_pesan untuk baris 99
# ✔️ Updated link_whatsapp untuk baris 100
# ✔️ Updated template_pesan untuk baris 100
# ✔️ Updated link_whatsapp untuk baris 101
# ✔️ Updated template_pesan untuk baris 101
# ✔️ Updated link_whatsapp untuk baris 102
# ✔️ Updated template_pesan untuk baris 102
#
# ⛔ Error Summary:
# ❌ Error saat memproses Mu’ammar Ahmad: Character "’" at index 11 in text is outside the range of characters supported by the font used: "helveticaB". Please consider using a Unicode font.
#
# ✅ Proses selesai!
