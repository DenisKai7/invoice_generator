# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKai7/invoice_generator/blob/main/fun_run_unipma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang diperlukan
# !pip install gspread pandas fpdf2 pyqrcode pypng requests pillow
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2

# Import library yang dibutuhkan
import gspread
from google.colab import auth
from google.auth import default
import pandas as pd
from fpdf import FPDF
import os
from google.colab import drive
from datetime import datetime
import requests
from io import BytesIO
from PIL import Image
import urllib.parse
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Autentikasi Google Colab dengan Google Sheets & Drive
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Inisialisasi Google Drive API
drive_service = build('drive', 'v3', credentials=creds)

# Mount Google Drive untuk menyimpan invoice
drive.mount('/content/drive')

# Buka spreadsheet
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1V3eNFJA4Sx93Uwi_NrFxG8mKQUpxhExr6aPea-PG-L8/edit?gid=0#gid=0"
sh = gc.open_by_url(spreadsheet_url)
worksheet = sh.get_worksheet(0)

# Ambil semua data dan periksa kolom yang tersedia
expected_headers = ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
records = worksheet.get_all_records(expected_headers=expected_headers)
df = pd.DataFrame.from_records(records)


# Periksa nama kolom yang sebenarnya
print("Kolom yang tersedia di spreadsheet:")
print(df.columns.tolist())

# Pastikan nama kolom sesuai dengan spreadsheet Anda
COLUMN_MAPPING = {
    'invoice_id': 'KODE_INVOICE',
    'name': 'NAMA',
    'category': 'KATEGORI',
    'barcode': 'BARCODE',
    'whatsapp': 'NO_WA',
    'address': 'ALAMAT'
}

# Path logo di Google Drive (sesuaikan dengan path Anda)
LOGO_DIES_PATH = '/content/drive/MyDrive/logo/diesnatalis 1-01.png'  # Ganti dengan path yang benar
LOGO_UNIPMA_PATH = '/content/drive/MyDrive/logo/Unipma.png'  # Ganti dengan path yang benar

class InvoicePDF(FPDF):
    def __init__(self, participant_data):
        super().__init__(format='A4', orientation='L')  # A4 Landscape
        self.participant_data = participant_data
        self.add_page()

    def header(self):
        # Tambahkan background dengan efek fade
        self._add_faded_background()

        # Tambahkan logo jika file ada
        try:
            # Logo Dies Natalis di kiri - ukuran disesuaikan
            if os.path.exists(LOGO_UNIPMA_PATH):
                self.image(LOGO_UNIPMA_PATH, x=15, y=15, w=30)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading UNIPMA logo: {e}")

        try:
            # Logo UNIPMA di kanan - ukuran disesuaikan
            if os.path.exists(LOGO_DIES_PATH):
                self.image(LOGO_DIES_PATH, x=210, y=0, w=100)  # Ukuran lebih besar untuk A4
        except Exception as e:
            print(f"⚠️ Error loading Dies Natalis logo: {e}")

        # Judul
        self.set_y(25)
        self.set_font('Arial', 'B', 18)
        self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
        self.set_font('Arial', 'I', 12)
        self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
        self.ln(5)

    def _add_faded_background(self):
        # Path ke gambar background (sesuaikan dengan path Anda)
        BG_IMAGE_PATH = '/content/drive/MyDrive/logo/asset diesnat fun run/bg1.jpg'  # Ganti dengan path gambar background Anda

        if os.path.exists(BG_IMAGE_PATH):
            try:
                # Simpan posisi Y saat ini
                current_y = self.get_y()

                # Geser gambar 20px ke kiri (nilai negatif) dan perluas lebar untuk menutupi area yang kosong
                x_offset = -15  # Sesuaikan nilai ini untuk mengatur seberapa jauh ke kiri
                adjusted_width = self.w + abs(x_offset)  # Tambahkan lebar untuk kompensasi pergeseran

                # Tambahkan gambar background dengan opacity rendah
                self.image(BG_IMAGE_PATH, x=x_offset, y=0, w=adjusted_width, h=self.h)

                # Tambahkan layer semi-transparan untuk efek fade
                self.set_fill_color(255, 255, 255, 200)  # Putih dengan alpha 200/255 (~78% opacity)
                self.rect(0, 0, self.w, self.h, style='F')

                # Kembalikan posisi Y
                self.set_y(current_y)
            except Exception as e:
                print(f"⚠️ Error adding background: {e}")
        else:
            print("⚠️ Background image not found, skipping...")

    def footer(self):
        # Thank you message di bagian footer tengah
        self.set_y(-15)
        self.set_font('Arial', 'I', 12)
        self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')

    def create_invoice(self):
        # Informasi invoice
        self.set_font('Arial', 'B', 14)
        self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')

        # Tanggal
        self.set_font('Arial', '', 11)
        self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
        self.ln(8)

        # Garis pemisah
        self.line(10, self.get_y(), 287, self.get_y())
        self.ln(10)

        # Layout 3 kolom dengan alignment yang presisi
        col_width = 85
        start_y = self.get_y()  # Simpan posisi Y awal

        # Kolom 1: Data peserta
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
        self.set_font('Arial', '', 11)

        # Simpan posisi Y untuk alignment
        y_details = self.get_y()

        # Initialize name_y at the beginning
        name_y = y_details

        # Nama (baseline untuk alignment)
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Nama:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
        self.ln(2)
        name_y = self.get_y()

        # WhatsApp jika ada
        if COLUMN_MAPPING["whatsapp"] in self.participant_data and self.participant_data[COLUMN_MAPPING["whatsapp"]]:
            whatsapp_num = str(self.participant_data[COLUMN_MAPPING["whatsapp"]])
            clean_number = ''.join(filter(str.isdigit, whatsapp_num))
            if clean_number.startswith('0'):
                clean_number = '+62' + clean_number[1:]
            elif not clean_number.startswith('62'):
                clean_number = '+62' + clean_number
            else:
                clean_number = '+' + clean_number

            self.set_font('Arial', 'B', 11)
            self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
            self.set_font('Arial', '', 11)
            self.cell(col_width, 6, clean_number, ln=1, align='L')
            self.ln(2)

        # Alamat jika ada
        if COLUMN_MAPPING["address"] in self.participant_data:
            address = self.participant_data[COLUMN_MAPPING["address"]]
            if pd.notna(address) and str(address).strip() != '':
                self.set_font('Arial', 'B', 11)
                self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
                self.set_font('Arial', '', 11)
                self.multi_cell(col_width, 6, str(address), align='L')
                self.ln(2)

        # Kategori
        self.set_font('Arial', 'B', 11)
        self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
        self.set_font('Arial', '', 11)
        self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
        self.ln(2)

        # Kolom 2: Detail pengambilan race pack (tengah)
        self.set_xy(120, y_details - 5)  # Sejajar dengan "PARTICIPANT DETAILS"
        self.set_font('Arial', 'B', 12)
        self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')

        # Posisikan konten race pack sejajar dengan "Name" di X=100
        self.set_xy(100, name_y - 10)  # X=100, Y sejajar dengan "Name"
        self.set_font('Arial', '', 11)

        # Format lengkap dengan indentasi yang tepat
        race_pack_content = [
          ("Tanggal:", 0),                     # Header - no indent
          ("- 30 Mei 2025", 0),                # Date 1 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-16.00", 10),       # Session 2 - indent 10
          ("- 31 Mei 2025", 0),                # Date 2 - no indent
          ("- Sesi 1: 08.00-11.00", 10),       # Session 1 - indent 10
          ("- Sesi 2: 13.00-15.00", 10),       # Session 2 - indent 10
          ("", 0),                             # Empty line
          ("Lokasi:", 0),                      # Location header - no indent
          ("Laboratorium Terpadu UNIPMA", 0)   # Location - no indent
        ]

        # Cetak dengan indentasi yang konsisten
        for line, indent in race_pack_content:
            self.set_x(120 + indent)
            self.cell(col_width - indent, 6, line, ln=1, align='L')

        # Kolom 3: Barcode/QR code
        if COLUMN_MAPPING["barcode"] in self.participant_data and self.participant_data[COLUMN_MAPPING["barcode"]]:
            try:
                response = requests.get(self.participant_data[COLUMN_MAPPING["barcode"]])
                img = Image.open(BytesIO(response.content))

                temp_img_path = f"/tmp/barcode_{self.participant_data[COLUMN_MAPPING['invoice_id']]}.png"
                img.save(temp_img_path)

                # Posisi di kolom kanan, sejajar dengan "Name"
                x_position = 220
                y_position = name_y - 15  # Adjust to align with "Name"

                self.image(temp_img_path, x=x_position, y=y_position, w=60)

                # Teks di bawah barcode
                self.set_xy(x_position, y_position + 56)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')

                # Teks di bawah barcode 2
                self.set_xy(x_position, y_position + 61)
                self.set_font('Arial', 'I', 10)
                self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')

                os.remove(temp_img_path)
            except Exception as e:
                print(f"⚠️ Error adding barcode: {e}")

        # Notes di bagian bawah - diposisikan lebih tinggi
        notes_y = max(self.get_y() + 1, 120)  # Mengurangi 15pt dari posisi sebelumnya
        self.set_xy(10, notes_y)
        self.set_font('Arial', 'I', 11)
        notes = [
            "Catatan:",
            "- Harap datang tepat waktu sesuai sesi yang dipilih",
            "- Tunjukkan barcode ini saat pengambilan race pack",
            "- Bawa identitas yang valid (KTP/SIM/KTM/KARTU PELAJAR)"
        ]
        for note in notes:
            self.cell(0, 6, note, ln=1, align='L')

def generate_invoice_pdf(participant_data):
    # Buat PDF
    pdf = InvoicePDF(participant_data)
    pdf.create_invoice()

    # Buat folder penyimpanan di Colab
    local_invoice_dir = "/content/invoices"
    os.makedirs(local_invoice_dir, exist_ok=True)

    # Simpan PDF lokal
    pdf_filename = f"FUN RUN UNIPMA_{participant_data[COLUMN_MAPPING['invoice_id']]}.pdf"
    local_pdf_path = f"{local_invoice_dir}/{pdf_filename}"
    pdf.output(local_pdf_path)

    return local_pdf_path, pdf_filename

def upload_to_drive(file_path, file_name, folder_id=None):
    """Upload file ke Google Drive dan set permissions"""
    file_metadata = {
        'name': file_name,
        'parents': [folder_id] if folder_id else None
    }

    media = MediaFileUpload(file_path, mimetype='application/pdf')

    file = drive_service.files().create(
        body=file_metadata,
        media_body=media,
        fields='id,webViewLink'
    ).execute()

    # Set permissions agar bisa diakses oleh siapa saja dengan link
    permission = {
        'type': 'anyone',
        'role': 'reader'
    }

    drive_service.permissions().create(
        fileId=file['id'],
        body=permission
    ).execute()

    return file['webViewLink']

def generate_whatsapp_link(phone_number):
    if pd.isna(phone_number) or not phone_number:
        return ""

    # Format nomor WhatsApp (62XXXXXXXXXX)
    clean_number = ''.join(filter(str.isdigit, str(phone_number)))
    if clean_number.startswith('0'):
        clean_number = '62' + clean_number[1:]
    elif not clean_number.startswith('62'):
        clean_number = '62' + clean_number
    return f"https://wa.me/{clean_number}"

def generate_message_template(participant_data, drive_link):
    # Format WhatsApp number dengan +62
    whatsapp_num = str(participant_data.get(COLUMN_MAPPING['whatsapp'], ''))
    if whatsapp_num:
        clean_number = ''.join(filter(str.isdigit, whatsapp_num))
        if clean_number.startswith('0'):
            clean_number = '+62' + clean_number[1:]
        elif not clean_number.startswith('62'):
            clean_number = '+62' + clean_number
        else:
            clean_number = '+' + clean_number
    else:
        clean_number = ''

    return f"""
Halo {participant_data[COLUMN_MAPPING['name']]},

Terima kasih telah mendaftar di *UNIPMA FUN RUN 5K 2025*!
Berikut invoice resmi Anda:

🔹 *Kode Invoice:* {participant_data[COLUMN_MAPPING['invoice_id']]}
🔹 *Kategori:* {participant_data[COLUMN_MAPPING['category']]}
🔹 *Alamat:* {participant_data[COLUMN_MAPPING['address']]}


📥 *Download Invoice:*
{drive_link}

*Info Pengambilan Race Pack:*
📅 *Tanggal:*
- 30 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-16.00)
- 31 Mei 2025: Sesi 1 (08.00-11.00) / Sesi 2 (13.00-15.00)
🏫 *Lokasi:* Laboratorium Terpadu UNIPMA

*Catatan:*
- Harap datang tepat waktu sesuai sesi yang dipilih
- Tunjukkan barcode yang ada pada invoice saat pengambilan racepack
- Bawa identitas yang valid(KTP/SIM/KTM/KARTU PELAJAR)

Mohon simpan invoice ini sebagai bukti pendaftaran.
Jika ada pertanyaan, hubungi kami via WhatsApp.

Salam,
*Panitia Unipma Fun Run 5K 2025*
"""

def process_all_participants():
    updates = []
    errors = []

    # ID folder tujuan di Google Drive (ganti dengan folder ID Anda)
    DRIVE_FOLDER_ID = '1A8ADXVlMOHPJsBhvaxZuBjL7egO3Wq2_'  # Ganti dengan folder ID tujuan

    for index, row in df.iterrows():
        try:
            invoice_id = row[COLUMN_MAPPING['invoice_id']]
            print(f"\nMemproses peserta: {row.get(COLUMN_MAPPING['name'], '')} (Invoice: {invoice_id})")

            # 1. Generate PDF
            local_pdf_path, pdf_filename = generate_invoice_pdf(row)

            # 2. Upload ke Google Drive dan dapatkan link
            drive_link = upload_to_drive(local_pdf_path, pdf_filename, DRIVE_FOLDER_ID)
            print(f"✅ Invoice diupload ke: {drive_link}")

            # 3. Generate link WhatsApp
            whatsapp_link = generate_whatsapp_link(row.get(COLUMN_MAPPING['whatsapp'], ''))
            updates.append((index, 'link_whatsapp', whatsapp_link))

            # 4. Buat template pesan
            message = generate_message_template(row, drive_link)
            updates.append((index, 'template_pesan', message))

            # 5. Bersihkan file lokal
            os.remove(local_pdf_path)

        except Exception as e:
            error_msg = f"❌ Error saat memproses {row.get(COLUMN_MAPPING['name'], '')}: {str(e)}"
            print(error_msg)
            errors.append((index, error_msg))

    # Update spreadsheet
    for update in updates:
        row_idx, col_name, value = update
        try:
            # Cari kolom yang sesuai
            col_names = [col.lower() for col in df.columns]
            target_col = col_name.lower()

            if target_col in col_names:
                col_idx = col_names.index(target_col) + 1  # +1 karena indeks spreadsheet mulai dari 1
                worksheet.update_cell(row_idx + 2, col_idx, value)
                print(f"✔️ Updated {col_name} untuk baris {row_idx + 2}")
            else:
                print(f"⚠️ Kolom {col_name} tidak ditemukan di spreadsheet")
        except Exception as e:
            print(f"❌ Gagal mengupdate spreadsheet untuk baris {row_idx}: {str(e)}")

    # Tampilkan error summary
    if errors:
        print("\n⛔ Error Summary:")
        for error in errors:
            print(error[1])

# Jalankan proses utama
process_all_participants()
print("\n✅ Proses selesai!")
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.11/dist-packages (6.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: fpdf2 in /usr/local/lib/python3.11/dist-packages (2.8.3)
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: pypng in /usr/local/lib/python3.11/dist-packages (0.20220715.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from gspread) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gspread) (1.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (4.58.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.38.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.4.26)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Kolom yang tersedia di spreadsheet:
# ['KODE_INVOICE', 'NAMA', 'KATEGORI', 'BARCODE', 'NO_WA', 'ALAMAT', 'link_whatsapp', 'template_pesan']
#
# Memproses peserta: Latifah sulistiyani (Invoice: LAT-1-3866)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# <ipython-input-11-b917e6fd07f6>:88: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 18)
# <ipython-input-11-b917e6fd07f6>:89: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, 'UNIPMA FUN RUN 5K 2025', 0, 1, 'C')
# <ipython-input-11-b917e6fd07f6>:90: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-11-b917e6fd07f6>:91: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 7, 'Official Invoice', 0, 1, 'C')
# <ipython-input-11-b917e6fd07f6>:129: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 14)
# <ipython-input-11-b917e6fd07f6>:130: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, f'INVOICE #{self.participant_data[COLUMN_MAPPING["invoice_id"]]}', 0, 1, 'L')
# <ipython-input-11-b917e6fd07f6>:133: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:134: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 8, f'Date: {datetime.now().strftime("%d %B %Y")}', 0, 1, 'L')
# <ipython-input-11-b917e6fd07f6>:146: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-11-b917e6fd07f6>:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PARTICIPANT DETAILS:', 0, 1, 'L')
# <ipython-input-11-b917e6fd07f6>:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:157: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-11-b917e6fd07f6>:158: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Nama:', ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:159: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:160: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["name"]]), ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:175: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-11-b917e6fd07f6>:176: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'No WhatsApp:', ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:177: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:178: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, clean_number, ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:185: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-11-b917e6fd07f6>:186: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Alamat:', ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:187: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:192: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 11)
# <ipython-input-11-b917e6fd07f6>:193: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, 'Kategori:', ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:194: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:195: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 6, str(self.participant_data[COLUMN_MAPPING["category"]]), ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:200: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'B', 12)
# <ipython-input-11-b917e6fd07f6>:201: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width, 8, 'PENGAMBILAN RACE PACK:', 0, 1, 'L')
# <ipython-input-11-b917e6fd07f6>:205: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', '', 11)
# <ipython-input-11-b917e6fd07f6>:224: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(col_width - indent, 6, line, ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:243: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-11-b917e6fd07f6>:244: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Scan this barcode for verification', 0, 1, 'C')
# <ipython-input-11-b917e6fd07f6>:248: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 10)
# <ipython-input-11-b917e6fd07f6>:249: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(60, 6, 'Thank you for joining our event!', 0, 1, 'C')
# <ipython-input-11-b917e6fd07f6>:258: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 11)
# <ipython-input-11-b917e6fd07f6>:266: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 6, note, ln=1, align='L')
# <ipython-input-11-b917e6fd07f6>:124: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font('Arial', 'I', 12)
# <ipython-input-11-b917e6fd07f6>:125: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=0 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   self.cell(0, 10, 'System By : Jofanza Denis Aldida & Yoga Gondrong', 0, 0, 'C')
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1tX-F_u7Ql1WjhggMzXwnDKRtzsq-bmkM/view?usp=drivesdk
#
# Memproses peserta: JIHAN ARVA ABIDAH (Invoice: JIH-1-9638)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1DxUV5XlDvNYhVHIsl2lFApI7exi-cPdq/view?usp=drivesdk
#
# Memproses peserta: muhamad salman al farisi (Invoice: MUH-1-6574)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/14O1ZMP8RA5dTFl9I86YigNWG5Gbh8pRW/view?usp=drivesdk
#
# Memproses peserta: INDRAJID JUNIANTA MUKTI (Invoice: IND-1-5831)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13K9FuNTTnyv0gqKtGFHOmvCv26u7aoev/view?usp=drivesdk
#
# Memproses peserta: Delvy Grace (Invoice: DEL-1-7102)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Ct7Kh_ihjxqO7ZDHCtq1r-Qu6PjWckD4/view?usp=drivesdk
#
# Memproses peserta: Khusnul Fatir (Invoice: KHU-1-7798)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1HvT0YbrBPBVRxCzjHynG4dIGp9aVb_yo/view?usp=drivesdk
#
# Memproses peserta: REYFAN ADITYA ALFARHI (Invoice: REY-1-4021)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cl8I0TP7VuKRkG3EmpRhuubs-rTkIJYn/view?usp=drivesdk
#
# Memproses peserta: Gisele Ardella Azalia (Invoice: GIS-1-2451)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1nZJrF8JoHEHjYMdyb0Nv5XTJ7qu_b1UQ/view?usp=drivesdk
#
# Memproses peserta: NOVITA AYU RAMANDANI (Invoice: NOV-1-6943)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1J9TmvkOKAAns3Slx8T1Yaadj4gFDno3g/view?usp=drivesdk
#
# Memproses peserta: Mardiana Putri Restianingtias  (Invoice: MAR-1-5743)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1isfsonUcdzxCa72VaGFw8y7AkYb40rLS/view?usp=drivesdk
#
# Memproses peserta: Reyhan Aldy Rimba pratama  (Invoice: REY-1-8282)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1XKDeJVse-OlYOPxZ2RTgsNKAuv94oO1y/view?usp=drivesdk
#
# Memproses peserta: MOCHAMMAD FALCO RIYANTO (Invoice: MOC-1-9381)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WotpheawS522Un6ZOEYj8FI-6OVx7hkt/view?usp=drivesdk
#
# Memproses peserta: Dwi Yoga Saputra (Invoice: DWI-1-4731)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Qjzdt88H8xl4Fjl8QnODfo90At6gNL33/view?usp=drivesdk
#
# Memproses peserta: Hadi Suryanto  (Invoice: HAD-1-3401)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11fn9pM-crVE63RW65RSMP4R8Mn8qZueh/view?usp=drivesdk
#
# Memproses peserta: Abdul Aziz (Invoice: ABD-1-6709)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1dUGqAk020HWNhvaMNPnkhePiW96s8b0f/view?usp=drivesdk
#
# Memproses peserta: Hanifah Nurul Hidayah  (Invoice: HAN-1-6494)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1C_Wb-7MLP_P1wAqrDilkCTtGLGom9IYv/view?usp=drivesdk
#
# Memproses peserta: Mishbahatul Lailiyah Daeng Lala (Invoice: MIS-1-9869)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Vqwr-q1fmU3gXpko7klKlqjp0etC3ICm/view?usp=drivesdk
#
# Memproses peserta: Muhammad Afiq Athalla Surya  (Invoice: MUH-1-0558)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1TFE6dookgCKa3YVhYtodF9m9psTOkMFz/view?usp=drivesdk
#
# Memproses peserta: ZAHRA AURELLIA SYIFA ROWIYANTI (Invoice: ZAH-1-9770)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1M8jlRs32CfY3cv_jPBCo6EJViWTWv3ae/view?usp=drivesdk
#
# Memproses peserta: DILLA PUTRI ANDINI  (Invoice: DIL-1-6691)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19T7g009K-x2wrh0GXZ3qiSl4AsNWA-TV/view?usp=drivesdk
#
# Memproses peserta: Zidni Karimatan Nisa (Invoice: ZID-1-6749)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vObg6wswfVQYddt195CvLl-B8SlJiiBs/view?usp=drivesdk
#
# Memproses peserta: DINA AGUSTIN  (Invoice: DIN-1-3909)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1A47jXEKkxPILHfh2CJeLEUPNa1hYLrkM/view?usp=drivesdk
#
# Memproses peserta: Lianawati  (Invoice: LIA-1-8320)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jJd7mxkzfh7IDMeKHmXEy7D9Jws3nTcW/view?usp=drivesdk
#
# Memproses peserta: Gilang Sebrian Pratama (Invoice: GIL-1-8865)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1JH8v5By-ny_IyJMWE7_Xo-Q5Jzc5ljQP/view?usp=drivesdk
#
# Memproses peserta: Ardha putra apriliano ananta  (Invoice: ARD-1-6485)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1R0ZeVboGmYuqGzHsVRRAqnZ6eKy70SMe/view?usp=drivesdk
#
# Memproses peserta: TSANI ROSIHAN MAJID (Invoice: TSA-1-5731)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1PK_wzdm8i58Y4KC4vT8kQtWFtSiB-3nv/view?usp=drivesdk
#
# Memproses peserta: Divia Sandhita Sekar Pertiwi  (Invoice: DIV-1-5045)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fNVMLAaRKJc4pyXW7eYblMbdukZ4UfRy/view?usp=drivesdk
#
# Memproses peserta: DIYANA PUTRI SANTOKO (Invoice: DIY-1-9369)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1R5kSa5omKVOybIFrui0R7JIm86k14cJP/view?usp=drivesdk
#
# Memproses peserta: Mamik wijayanti (Invoice: MAM-1-3515)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11ciiRqt14xTURcqYQyQZ_6VSG0DqEsvb/view?usp=drivesdk
#
# Memproses peserta: INNEZ ADRIANA PUTRI MAHARANI (Invoice: INN-1-4121)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OOnAoWIpd8dDI4TAvi5k4xL_flGY5f6m/view?usp=drivesdk
#
# Memproses peserta: Anggun Novita Wulandari  (Invoice: ANG-1-1831)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1g5mVbY9fXjeYQYHXK9qXwXMyjlSj4fSB/view?usp=drivesdk
#
# Memproses peserta: Shevany Valencia Putri (Invoice: SHE-1-6099)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Piv5oCQpozdxRxHABPtzJiMzA0g4vLv7/view?usp=drivesdk
#
# Memproses peserta: Septa arifin putra (Invoice: SEP-1-3970)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1_YEsKNoUbfW2y6Ph3jhWDyk-TiUNSwiH/view?usp=drivesdk
#
# Memproses peserta: Reni Nurhayati (Invoice: REN-1-2585)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1HnullnC6LUCiMXlioKY3LF6drgyHboOc/view?usp=drivesdk
#
# Memproses peserta: vico chelsie fabian mauladani  (Invoice: VIC-1-6488)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ihhGEfYsCrmsiNWQosDAmQs9TkTVgpuF/view?usp=drivesdk
#
# Memproses peserta: Rendy kurniawan (Invoice: REN-1-4040)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Gz15grNRkgke-KkRB9MfwDucqnO4SqjP/view?usp=drivesdk
#
# Memproses peserta: LATHIFAH KAMILIA ALFANINDYA (Invoice: LAT-1-6744)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1BCbXE2vrkOTlcwVGHDnIGs0PEWYIUKFb/view?usp=drivesdk
#
# Memproses peserta: Alfan Muhammad Santoso (Invoice: ALF-1-0627)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fwbgPn6idboCZGwZpnttLRxGzQfPHOHo/view?usp=drivesdk
#
# Memproses peserta: PUTRI MAYA PETRICYA (Invoice: PUT-1-9744)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1t60RzehqO-c7-trgCnDjGB6Q63Y7wX35/view?usp=drivesdk
#
# Memproses peserta: ALFIDA ROUDHOTUL ISTIA NUR WIBOWO  (Invoice: ALF-1-5806)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1vxE1eLbMj0JLfmWMHQy4JU9ZBoLIsNWD/view?usp=drivesdk
#
# Memproses peserta: ALFI NUR HAMIDAH (Invoice: ALF-1-7996)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1FvPUqS93hK7qTj89cH8v5u93WuYRz89d/view?usp=drivesdk
#
# Memproses peserta: Bryan Andhi Pamungkas (Invoice: BRY-1-8914)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xtxFusnUns2MsOzHU-vHP09xRy-iw7rs/view?usp=drivesdk
#
# Memproses peserta: Nindi Prasetya Utama (Invoice: NIN-1-5278)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1h3mVOo5Qw89LJaFo4TNEZt2r_lwwypUE/view?usp=drivesdk
#
# Memproses peserta: JANITRA LUTHFI MAULIDA  (Invoice: JAN-1-4493)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/15MrORRYtntkz9sBa2AtNqMMOnsO0mqKZ/view?usp=drivesdk
#
# Memproses peserta: Rico Dwi Setyawan  (Invoice: RIC-1-6038)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1c3lLFR_kFfqDcCjSoUWAoJq0CYLmsBPL/view?usp=drivesdk
#
# Memproses peserta: Alifiya Nur Aini (Invoice: ALI-1-5541)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Rn3IJVatF00SQtnpuMoF94Zu4JcGhtcV/view?usp=drivesdk
#
# Memproses peserta: RASYAD ADYUTA ARKAN (Invoice: RAS-1-6113)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1jqwZldL0GR2xapU6rJvxhqrtLl6kjh_R/view?usp=drivesdk
#
# Memproses peserta: Girang Lumpati Anaking  (Invoice: GIR-1-6094)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1RSjJDmyn4ea3s0WTP4dTi6MBPbOVclWV/view?usp=drivesdk
#
# Memproses peserta: GALUH PRATIWI (Invoice: GAL-1-4174)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1sAhQPtLgS3fCETsPkhiR0pRMBzpTNblT/view?usp=drivesdk
#
# Memproses peserta: Farhan Aditya Saputra (Invoice: FAR-1-9523)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mxQqo0FIZY1g39yLwchH-C8VQXCw_kKY/view?usp=drivesdk
#
# Memproses peserta: RIDHO FAJAR ANGGORO (Invoice: RID-1-0933)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1FaUopFhjVavnvoGnElSDCPDxr8HBstfg/view?usp=drivesdk
#
# Memproses peserta: PUTRI AULIA NATASA (Invoice: PUT-1-9734)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1rXJ0ZsWuPSkge7q7Gd4_yRkmqmqKU8NV/view?usp=drivesdk
#
# Memproses peserta: Ibnu hanifan (Invoice: IBN-1-3528)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1mAJd67cWLVq3BFn9stJu4ESoQbDsMYVa/view?usp=drivesdk
#
# Memproses peserta: HUMAIRA RAFIFATU RIFDA (Invoice: HUM-1-6712)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ixyOlp-nMvZ2S3OOxCE1V6tJZDqDqD3h/view?usp=drivesdk
#
# Memproses peserta: Sheilla Azzahra (Invoice: SHE-1-9657)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MP4-7pLeMI6Tesj-RmZOnjbJV975LXae/view?usp=drivesdk
#
# Memproses peserta: Muhammad Zikvy (Invoice: MUH-1-4881)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1G2dvbSUWpsgEwTVwV2y5dOoUFUfG7-pL/view?usp=drivesdk
#
# Memproses peserta: Muhamad Sakti Cahaya Alamsyah  (Invoice: MUH-1-5867)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1S-PGpLvw1S-nZ-hO9eVqfzty6AdPoP6v/view?usp=drivesdk
#
# Memproses peserta: Rizal fatoni putra (Invoice: RIZ-1-8496)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1NWVzJVKgvTJjP9iZ2FAK3XsQS8FhZs-X/view?usp=drivesdk
#
# Memproses peserta: Butti Mila Desvi Mandasari (Invoice: BUT-1-8383)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/129VGe7kqQ4UmmnrdfW__gaWoTl7c84fq/view?usp=drivesdk
#
# Memproses peserta: ALFAJAR MAHFUDZ MA'ARIF (Invoice: ALF-1-1517)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fwHh1a6WBEI5hKKd8NPpx-wRUJ1w8z13/view?usp=drivesdk
#
# Memproses peserta: Muhammad randitya andika putra (Invoice: MUH-1-6277)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1M3_wLmkH7nNoccDLzD5VaV93OBN-XsX0/view?usp=drivesdk
#
# Memproses peserta: Yollanda Azka Helmia (Invoice: YOL-1-9449)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1hLeLq2FCuwVFW9SOUv4h2mFz8wjBzlas/view?usp=drivesdk
#
# Memproses peserta: rayhan nafi aldiansyah (Invoice: RAY-1-9755)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1OfDQ63LONCryUys6wDDU7D9Syg5c5Qqs/view?usp=drivesdk
#
# Memproses peserta: ADITYA RIZKI PUTRA SUBAGIYO  (Invoice: ADI-1-9342)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1SuzktoJ0VyPeSz-wybJwKDAPkOAabhtI/view?usp=drivesdk
#
# Memproses peserta: Kevin Nureca Widiyanto (Invoice: KEV-1-4836)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/19FPzwbSQQ_lqMjK8YqOk_pY5bnFXSRUr/view?usp=drivesdk
#
# Memproses peserta: Pandu Pradana Putra (Invoice: PAN-1-6774)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1cOcuPpk3FGkMeckXbNf-vlo7N3so9FDB/view?usp=drivesdk
#
# Memproses peserta: Tria Utami (Invoice: TRI-1-3847)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1S4CUr7KRkExTg_IszPdoInYmZpmB76rt/view?usp=drivesdk
#
# Memproses peserta: Tri Mardiana (Invoice: TRI-1-8345)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Tnxxgc1NlO8Mjmn3BtcOxf3Azgv98p9Q/view?usp=drivesdk
#
# Memproses peserta: ERA GRADIPUTRA HARDIANTO (Invoice: ERA-1-9196)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13JYQl3G5YcD3amrZYMqbtMXqDwt8550Z/view?usp=drivesdk
#
# Memproses peserta: NUR MUHAMMAD TEGAR (Invoice: NUR-1-0420)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1PffM91bZe1Js1kA6sErHK7eKlu_x63Zq/view?usp=drivesdk
#
# Memproses peserta: ANNISA RIZKI CAHYANI  (Invoice: ANN-1-5449)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1BnQ1y-NVPNjLf0s3HIfShJgdaY4EyNFo/view?usp=drivesdk
#
# Memproses peserta: NAURA KENZIE ZAHARANI (Invoice: NAU-1-3767)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fxG95d4MggqX8ZBywwzEw0wdQsqWe-IO/view?usp=drivesdk
#
# Memproses peserta: Marisa Aulia Zaharani (Invoice: MAR-1-3857)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1HI-wxwaNVdkBMDXAfeoo7ZOtxZwXFbVg/view?usp=drivesdk
#
# Memproses peserta: ADAM PUTERA BUHANA (Invoice: ADA-1-1310)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1sDkLCPJCEzHTPjxc12lvWrhITeRgQVyT/view?usp=drivesdk
#
# Memproses peserta: Anif Kurniawan N (Invoice: ANI-1-6065)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1BFodf67OxpPxy_p6OaG6BxA8URELJ-t6/view?usp=drivesdk
#
# Memproses peserta: Nicko Febryan Primandika (Invoice: NIC-1-2804)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1AyEyQAl07dHBFbHBk-33-EpXe-Slldba/view?usp=drivesdk
#
# Memproses peserta: Bareeq Suta Soesilo (Invoice: BAR-1-2872)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1nmNLqbv93QQGO-oAwIVLTIZTxwshgrGh/view?usp=drivesdk
#
# Memproses peserta: ACHRIAN NOVRADIPUTRA (Invoice: ACH-1-1600)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1LWQPI7-pWFulg91HNJ3-4tHpNm82CRjl/view?usp=drivesdk
#
# Memproses peserta: Prima Dita Ernanda (Invoice: PRI-1-0833)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1MzZLv9jZA8b5fsZSIrLsHohpNzD80zWc/view?usp=drivesdk
#
# Memproses peserta: Hernan Suta Soesilo (Invoice: HER-1-6371)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1WsB2lLT-X2hD5_d_FCYMMuibdPxZXTXy/view?usp=drivesdk
#
# Memproses peserta: DEWI ASMA'UL QUSNA (Invoice: DEW-1-2991)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11QWkP37LZm9FdX6UvSgli36MLN4wXa2C/view?usp=drivesdk
#
# Memproses peserta: Syarif Rafa Fausta (Invoice: SYA-1-0806)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Wfl9wy6pkfH3kFqYRUl6TmNux0pDFbyI/view?usp=drivesdk
#
# Memproses peserta: Nadya Kholidah Rahmawati (Invoice: NAD-1-2738)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1r_qcWXv76nic1Eq3QeNuufhJjPtgtdyG/view?usp=drivesdk
#
# Memproses peserta: SHERLYNDA RAMADHANI WIHAYANA (Invoice: SHE-1-2097)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1xL__s8nMdv-GYcHN2NpoOXiy24tJX6pE/view?usp=drivesdk
#
# Memproses peserta: Qalisa Galuh p.j (Invoice: QAL-1-7157)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1VCmXV5e2BPEd34JJc0scsQOw4Js1G-LI/view?usp=drivesdk
#
# Memproses peserta: AJI MANSUR CHOIRU MUADIB (Invoice: AJI-1-7426)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/16Fk-FNFZN89_QcHZBzsyYyvTKhrrbzda/view?usp=drivesdk
#
# Memproses peserta: Yuliana Rachmawati Awaliyah (Invoice: YUL-1-5838)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1bjDejkEI5maaHKDhCzuQJdEg3rno7C0E/view?usp=drivesdk
#
# Memproses peserta: Ibrahim Maulana Ismail (Invoice: IBR-1-5838)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Hwq7dsMxJqvnQsrdROU1FyZU93gLehCc/view?usp=drivesdk
#
# Memproses peserta: FATIH FAUZAN ISMAIL (Invoice: FAT-1-0116)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1lTTu9-63xJB4FgiWDv5TViU8J5H7ClL3/view?usp=drivesdk
#
# Memproses peserta: Marta Dinata Wijaya (Invoice: MAR-1-3360)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1LzGT0IsamF-bxA-2yixkdoFIE1mcmJo_/view?usp=drivesdk
#
# Memproses peserta: ADIEF PRABOWO (Invoice: ADI-1-4258)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/13y8lGQig4c8J39nA2lY6_txaodEXiWxK/view?usp=drivesdk
#
# Memproses peserta: YUDHA ARYA PRATAMA (Invoice: YUD-1-5443)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fKP7NukxkPH6Rco7LQ0jsFn7ji3ElvLF/view?usp=drivesdk
#
# Memproses peserta: Diva Rahma Romadoni (Invoice: DIV-1-4800)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1UMD-cKiE72yd5VRcy1g3bhmDLN6UuDcT/view?usp=drivesdk
#
# Memproses peserta: Eva Widyawati (Invoice: EVA-1-3972)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1--Fx2MWHXIBV6PiRGRdNp-OssWEaK8yI/view?usp=drivesdk
#
# Memproses peserta: Miftahul chanafi (Invoice: MIF-1-7308)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1-2n-u8meJovPHeq37_PT3a0NBWUmcxPZ/view?usp=drivesdk
#
# Memproses peserta: EDRIAN KESUMA PUTRA (Invoice: EDR-1-6676)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/11oKCh-jYTWvGrseYyilZOI4J26HKntFC/view?usp=drivesdk
#
# Memproses peserta: MARGARETHA REGINA VINSA TASIABE  (Invoice: MAR-1-9243)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1ZaMj41mDCqyERPm1h3Bda7y1Vivu_CjU/view?usp=drivesdk
#
# Memproses peserta: AZ ZAHRA YULIA GITA ANIVA (Invoice: AZ -1-9098)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1A_n966BOjo280I4Objjzie50nzEo7LPS/view?usp=drivesdk
#
# Memproses peserta: Rafisya Azka Qotrunnada  (Invoice: RAF-1-3191)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/10vVfBO5H4iX0cUg2uU-LJ5R-Hd-rLK8t/view?usp=drivesdk
#
# Memproses peserta: Paulus Bimo Satrio Aji (Invoice: PAU-1-8430)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1fAknQUegRHagxWx8VAd1pyQlnR8mCmf7/view?usp=drivesdk
#
# Memproses peserta: PURNO WIDODO (Invoice: PUR-1-1141)
# ⚠️ Error adding background: FPDF.set_fill_color() takes from 2 to 4 positional arguments but 5 were given
# ✅ Invoice diupload ke: https://drive.google.com/file/d/1Y0oGwliFIRv_-YSWbjFeY1hH2kNk9I64/view?usp=drivesdk
# ✔️ Updated link_whatsapp untuk baris 2
# ✔️ Updated template_pesan untuk baris 2
# ✔️ Updated link_whatsapp untuk baris 3
# ✔️ Updated template_pesan untuk baris 3
# ✔️ Updated link_whatsapp untuk baris 4
# ✔️ Updated template_pesan untuk baris 4
# ✔️ Updated link_whatsapp untuk baris 5
# ✔️ Updated template_pesan untuk baris 5
# ✔️ Updated link_whatsapp untuk baris 6
# ✔️ Updated template_pesan untuk baris 6
# ✔️ Updated link_whatsapp untuk baris 7
# ✔️ Updated template_pesan untuk baris 7
# ✔️ Updated link_whatsapp untuk baris 8
# ✔️ Updated template_pesan untuk baris 8
# ✔️ Updated link_whatsapp untuk baris 9
# ✔️ Updated template_pesan untuk baris 9
# ✔️ Updated link_whatsapp untuk baris 10
# ✔️ Updated template_pesan untuk baris 10
# ✔️ Updated link_whatsapp untuk baris 11
# ✔️ Updated template_pesan untuk baris 11
# ✔️ Updated link_whatsapp untuk baris 12
# ✔️ Updated template_pesan untuk baris 12
# ✔️ Updated link_whatsapp untuk baris 13
# ✔️ Updated template_pesan untuk baris 13
# ✔️ Updated link_whatsapp untuk baris 14
# ✔️ Updated template_pesan untuk baris 14
# ✔️ Updated link_whatsapp untuk baris 15
# ✔️ Updated template_pesan untuk baris 15
# ✔️ Updated link_whatsapp untuk baris 16
# ✔️ Updated template_pesan untuk baris 16
# ✔️ Updated link_whatsapp untuk baris 17
# ✔️ Updated template_pesan untuk baris 17
# ✔️ Updated link_whatsapp untuk baris 18
# ✔️ Updated template_pesan untuk baris 18
# ✔️ Updated link_whatsapp untuk baris 19
# ✔️ Updated template_pesan untuk baris 19
# ✔️ Updated link_whatsapp untuk baris 20
# ✔️ Updated template_pesan untuk baris 20
# ✔️ Updated link_whatsapp untuk baris 21
# ✔️ Updated template_pesan untuk baris 21
# ✔️ Updated link_whatsapp untuk baris 22
# ✔️ Updated template_pesan untuk baris 22
# ✔️ Updated link_whatsapp untuk baris 23
# ✔️ Updated template_pesan untuk baris 23
# ✔️ Updated link_whatsapp untuk baris 24
# ✔️ Updated template_pesan untuk baris 24
# ✔️ Updated link_whatsapp untuk baris 25
# ✔️ Updated template_pesan untuk baris 25
# ✔️ Updated link_whatsapp untuk baris 26
# ✔️ Updated template_pesan untuk baris 26
# ✔️ Updated link_whatsapp untuk baris 27
# ✔️ Updated template_pesan untuk baris 27
# ✔️ Updated link_whatsapp untuk baris 28
# ✔️ Updated template_pesan untuk baris 28
# ✔️ Updated link_whatsapp untuk baris 29
# ✔️ Updated template_pesan untuk baris 29
# ✔️ Updated link_whatsapp untuk baris 30
# ✔️ Updated template_pesan untuk baris 30
# ✔️ Updated link_whatsapp untuk baris 31
# ✔️ Updated template_pesan untuk baris 31
# ✔️ Updated link_whatsapp untuk baris 32
# ✔️ Updated template_pesan untuk baris 32
# ✔️ Updated link_whatsapp untuk baris 33
# ✔️ Updated template_pesan untuk baris 33
# ✔️ Updated link_whatsapp untuk baris 34
# ✔️ Updated template_pesan untuk baris 34
# ✔️ Updated link_whatsapp untuk baris 35
# ✔️ Updated template_pesan untuk baris 35
# ✔️ Updated link_whatsapp untuk baris 36
# ✔️ Updated template_pesan untuk baris 36
# ✔️ Updated link_whatsapp untuk baris 37
# ✔️ Updated template_pesan untuk baris 37
# ✔️ Updated link_whatsapp untuk baris 38
# ✔️ Updated template_pesan untuk baris 38
# ✔️ Updated link_whatsapp untuk baris 39
# ✔️ Updated template_pesan untuk baris 39
# ✔️ Updated link_whatsapp untuk baris 40
# ✔️ Updated template_pesan untuk baris 40
# ✔️ Updated link_whatsapp untuk baris 41
# ✔️ Updated template_pesan untuk baris 41
# ✔️ Updated link_whatsapp untuk baris 42
# ✔️ Updated template_pesan untuk baris 42
# ✔️ Updated link_whatsapp untuk baris 43
# ✔️ Updated template_pesan untuk baris 43
# ✔️ Updated link_whatsapp untuk baris 44
# ✔️ Updated template_pesan untuk baris 44
# ✔️ Updated link_whatsapp untuk baris 45
# ✔️ Updated template_pesan untuk baris 45
# ✔️ Updated link_whatsapp untuk baris 46
# ✔️ Updated template_pesan untuk baris 46
# ✔️ Updated link_whatsapp untuk baris 47
# ✔️ Updated template_pesan untuk baris 47
# ✔️ Updated link_whatsapp untuk baris 48
# ✔️ Updated template_pesan untuk baris 48
# ✔️ Updated link_whatsapp untuk baris 49
# ✔️ Updated template_pesan untuk baris 49
# ✔️ Updated link_whatsapp untuk baris 50
# ✔️ Updated template_pesan untuk baris 50
# ✔️ Updated link_whatsapp untuk baris 51
# ✔️ Updated template_pesan untuk baris 51
# ✔️ Updated link_whatsapp untuk baris 52
# ✔️ Updated template_pesan untuk baris 52
# ✔️ Updated link_whatsapp untuk baris 53
# ✔️ Updated template_pesan untuk baris 53
# ✔️ Updated link_whatsapp untuk baris 54
# ✔️ Updated template_pesan untuk baris 54
# ✔️ Updated link_whatsapp untuk baris 55
# ✔️ Updated template_pesan untuk baris 55
# ✔️ Updated link_whatsapp untuk baris 56
# ✔️ Updated template_pesan untuk baris 56
# ✔️ Updated link_whatsapp untuk baris 57
# ✔️ Updated template_pesan untuk baris 57
# ✔️ Updated link_whatsapp untuk baris 58
# ✔️ Updated template_pesan untuk baris 58
# ✔️ Updated link_whatsapp untuk baris 59
# ✔️ Updated template_pesan untuk baris 59
# ✔️ Updated link_whatsapp untuk baris 60
# ✔️ Updated template_pesan untuk baris 60
# ✔️ Updated link_whatsapp untuk baris 61
# ✔️ Updated template_pesan untuk baris 61
# ✔️ Updated link_whatsapp untuk baris 62
# ✔️ Updated template_pesan untuk baris 62
# ✔️ Updated link_whatsapp untuk baris 63
# ✔️ Updated template_pesan untuk baris 63
# ✔️ Updated link_whatsapp untuk baris 64
# ✔️ Updated template_pesan untuk baris 64
# ✔️ Updated link_whatsapp untuk baris 65
# ✔️ Updated template_pesan untuk baris 65
# ✔️ Updated link_whatsapp untuk baris 66
# ✔️ Updated template_pesan untuk baris 66
# ✔️ Updated link_whatsapp untuk baris 67
# ✔️ Updated template_pesan untuk baris 67
# ✔️ Updated link_whatsapp untuk baris 68
# ✔️ Updated template_pesan untuk baris 68
# ✔️ Updated link_whatsapp untuk baris 69
# ✔️ Updated template_pesan untuk baris 69
# ✔️ Updated link_whatsapp untuk baris 70
# ✔️ Updated template_pesan untuk baris 70
# ✔️ Updated link_whatsapp untuk baris 71
# ✔️ Updated template_pesan untuk baris 71
# ✔️ Updated link_whatsapp untuk baris 72
# ✔️ Updated template_pesan untuk baris 72
# ✔️ Updated link_whatsapp untuk baris 73
# ✔️ Updated template_pesan untuk baris 73
# ✔️ Updated link_whatsapp untuk baris 74
# ✔️ Updated template_pesan untuk baris 74
# ✔️ Updated link_whatsapp untuk baris 75
# ✔️ Updated template_pesan untuk baris 75
# ✔️ Updated link_whatsapp untuk baris 76
# ✔️ Updated template_pesan untuk baris 76
# ✔️ Updated link_whatsapp untuk baris 77
# ✔️ Updated template_pesan untuk baris 77
# ✔️ Updated link_whatsapp untuk baris 78
# ✔️ Updated template_pesan untuk baris 78
# ✔️ Updated link_whatsapp untuk baris 79
# ✔️ Updated template_pesan untuk baris 79
# ✔️ Updated link_whatsapp untuk baris 80
# ✔️ Updated template_pesan untuk baris 80
# ✔️ Updated link_whatsapp untuk baris 81
# ✔️ Updated template_pesan untuk baris 81
# ✔️ Updated link_whatsapp untuk baris 82
# ✔️ Updated template_pesan untuk baris 82
# ✔️ Updated link_whatsapp untuk baris 83
# ✔️ Updated template_pesan untuk baris 83
# ✔️ Updated link_whatsapp untuk baris 84
# ✔️ Updated template_pesan untuk baris 84
# ✔️ Updated link_whatsapp untuk baris 85
# ✔️ Updated template_pesan untuk baris 85
# ✔️ Updated link_whatsapp untuk baris 86
# ✔️ Updated template_pesan untuk baris 86
# ✔️ Updated link_whatsapp untuk baris 87
# ✔️ Updated template_pesan untuk baris 87
# ✔️ Updated link_whatsapp untuk baris 88
# ✔️ Updated template_pesan untuk baris 88
# ✔️ Updated link_whatsapp untuk baris 89
# ✔️ Updated template_pesan untuk baris 89
# ✔️ Updated link_whatsapp untuk baris 90
# ✔️ Updated template_pesan untuk baris 90
# ✔️ Updated link_whatsapp untuk baris 91
# ✔️ Updated template_pesan untuk baris 91
# ✔️ Updated link_whatsapp untuk baris 92
# ✔️ Updated template_pesan untuk baris 92
# ✔️ Updated link_whatsapp untuk baris 93
# ✔️ Updated template_pesan untuk baris 93
# ✔️ Updated link_whatsapp untuk baris 94
# ✔️ Updated template_pesan untuk baris 94
# ✔️ Updated link_whatsapp untuk baris 95
# ✔️ Updated template_pesan untuk baris 95
# ✔️ Updated link_whatsapp untuk baris 96
# ✔️ Updated template_pesan untuk baris 96
# ✔️ Updated link_whatsapp untuk baris 97
# ✔️ Updated template_pesan untuk baris 97
# ✔️ Updated link_whatsapp untuk baris 98
# ✔️ Updated template_pesan untuk baris 98
# ✔️ Updated link_whatsapp untuk baris 99
# ✔️ Updated template_pesan untuk baris 99
# ✔️ Updated link_whatsapp untuk baris 100
# ✔️ Updated template_pesan untuk baris 100
# ✔️ Updated link_whatsapp untuk baris 101
# ✔️ Updated template_pesan untuk baris 101
# ✔️ Updated link_whatsapp untuk baris 102
# ✔️ Updated template_pesan untuk baris 102
#
# ✅ Proses selesai!
